# %%
# %%capture
# !pip install -q -U bitsandbytes
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install transformers==4.31
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git
# !pip install -q datasets
# !pip install evaluate
# !pip install -qqq trl==0.7.1
# !pip install torch

# %%
# !pip install -q rouge_score
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for rouge_score (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# %cd /content/drive/MyDrive/DLT_Project/
# Out:
# /content/drive/MyDrive/DLT_Project

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import transformers
from torch.optim import Adam
from tqdm import tqdm
import utils
from utils import *
import json
import pandas as pd
import torch
# from torch.utils.data import Dataset, DataLoader
import time
import evaluate
from datasets import Dataset, load_dataset
import random
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

# %%
dir_path = '/content/drive/MyDrive/DLT_Project/'
os.chdir(dir_path)

# %%
with open(f"{dir_path}/train.json") as input_file:
        train_data = json.load(input_file)

with open(f"{dir_path}/dev.json") as input_file:
        valid_data = json.load(input_file)

with open(f"{dir_path}/test.json") as input_file:
        test_data = json.load(input_file)

# %%
assert len(train_data) == 6251, "The train data seems to be off, please check"
assert len(valid_data) == 883, "The validation data seems to be off, please check"
assert len(test_data) == 1147, "The test data seems to be off, please check"

# %%
df_train_1step_serialized =pd.read_csv(f"{dir_path}/df_train_1step_serialized.csv")

# %%
df_train_1step_serialized.shape
# Out:
# (3532, 9)

# %%
train_data=pd.DataFrame(train_data).merge(df_train_1step_serialized[['id','serialized_text_gpt35']],on='id',how='inner').to_dict(orient='records')

# %%
len(train_data)
# Out:
# 3532

# %%
train_data[0].keys()
# Out:
# dict_keys(['pre_text', 'post_text', 'filename', 'table_ori', 'table', 'qa', 'id', 'table_retrieved', 'text_retrieved', 'table_retrieved_all', 'text_retrieved_all', 'serialized_text_gpt35'])

# %%
def prepare_data(json_data, verbose=True, split = 'train'):
    net=[]
    err_cnt=0
    for example in json_data:
        question = example["qa"]["question"]
        table = example["table"]
        id=example["id"]
        table_ori=example["table_ori"]
        answer_steps=example["qa"]["steps"]
        if split == 'train':
            serialized_text=example["serialized_text_gpt35"]
            table_text = ""
            for row in table[1:]:
                this_sent = table_row_to_text(table[0], row)
                table_text += this_sent
            try:
                steps_text = format_steps(example["qa"]["steps"])
                inputs = {"id":id, "context": serialized_text, "question": question, "answer": steps_text,\
                          "table":table_ori,"answer_steps":answer_steps}
                net.append(inputs)
            except:
                err_cnt+=1
                if verbose:
                    print ("-"*25)
                    print (example["filename"])
                    print (example["qa"]["steps"])
                    print ("-"*25+"\n")
        else:
            table_text = ""
            for row in table[1:]:
                this_sent = table_row_to_text(table[0], row)
                table_text += this_sent
            try:
                steps_text = format_steps(example["qa"]["steps"])
                inputs = {"id":id, "context": table_text, "question": question, "answer": steps_text,\
                          "table":table_ori,"answer_steps":answer_steps}
                net.append(inputs)
            except:
                err_cnt+=1
                if verbose:
                    print ("-"*25)
                    print (example["filename"])
                    print (example["qa"]["steps"])
                    print ("-"*25+"\n")

    if err_cnt>0:
        print ("Net Errors:",err_cnt)
    return net

# %%
## Preparing huggingface dataset
data_splits = {'train': train_data, 'valid': valid_data, 'test': test_data}
datasets = {split: Dataset.from_pandas(pd.DataFrame(prepare_data(data, False, split))) for split, data in data_splits.items()}
# Out:
# Net Errors: 35
# Net Errors: 39

# %%
datasets
# Out:
# {'train': Dataset({
#      features: ['id', 'context', 'question', 'answer', 'table', 'answer_steps'],
#      num_rows: 3532
#  }),
#  'valid': Dataset({
#      features: ['id', 'context', 'question', 'answer', 'table', 'answer_steps'],
#      num_rows: 848
#  }),
#  'test': Dataset({
#      features: ['id', 'context', 'question', 'answer', 'table', 'answer_steps'],
#      num_rows: 1108
#  })}

# %%
step_pattern = r"Step \d+"
import re

# %%
def num_steps_dict_fn(example):
    example["num_steps"] = len(re.findall(step_pattern, example["answer"]))
    return example

# %%
datasets['train']=datasets['train'].map(num_steps_dict_fn)
datasets['valid']=datasets['valid'].map(num_steps_dict_fn)
datasets['test']=datasets['test'].map(num_steps_dict_fn)
# Out:
# Map:   0%|          | 0/3532 [00:00<?, ? examples/s]
# Map:   0%|          | 0/848 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1108 [00:00<?, ? examples/s]

# %%
datasets['train']=datasets['train'].filter(lambda example: example['num_steps']==1)
datasets['valid']=datasets['valid'].filter(lambda example: example['num_steps']==1)
datasets['test']=datasets['test'].filter(lambda example: example['num_steps']==1)
# Out:
# Filter:   0%|          | 0/3532 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/848 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1108 [00:00<?, ? examples/s]

# %%
datasets
# Out:
# {'train': Dataset({
#      features: ['id', 'context', 'question', 'answer', 'table', 'answer_steps', 'num_steps'],
#      num_rows: 3532
#  }),
#  'valid': Dataset({
#      features: ['id', 'context', 'question', 'answer', 'table', 'answer_steps', 'num_steps'],
#      num_rows: 489
#  }),
#  'test': Dataset({
#      features: ['id', 'context', 'question', 'answer', 'table', 'answer_steps', 'num_steps'],
#      num_rows: 616
#  })}

# %%
import getpass

# Prompt for the Hugging Face token
hf_token = getpass.getpass("Enter your Hugging Face token: ")

import os
os.environ['HUGGINGFACE_TOKEN'] = hf_token
# Out:
# Enter your Hugging Face token: ··········

# %%
model_id =  "meta-llama/Llama-2-7b-hf"
# model_id = "meta-llama/Llama-2-7b-chat-hf"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=bnb_config, device_map="auto",use_auth_token=hf_token)

tokenizer = AutoTokenizer.from_pretrained(model_id,use_auth_token=hf_token)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Out:
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:2193: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1714: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
def format_instruction(id, context: str, question: str, answer: str,table , answer_steps, num_steps):
  prompt = f"""### Instruction: Act as a financial analyst adept in reading Earning Reports and Financial Documents.
  Answer the question in a single step by extracting relevant values from the context given below. Perform the necessary arithmetic operation.

  ### Context:
  {context}

  ### Question:
  {question}

  ### Answer:
  {answer}
  """.strip()
  return prompt

# %%
index = 5

# %%
print(format_instruction(**datasets['train'][index]))
# Out:
# ### Instruction: Act as a financial analyst adept in reading Earning Reports and Financial Documents.
#   Answer the question in a single step by extracting relevant values from the context given below. Perform the necessary arithmetic operation.
#
#   ### Context:
#   The table shows the various expenses incurred during a reorganization process. The expenses include a labor-related deemed claim of $1,733, aircraft and facility financing renegotiations and rejections costing $325, fair value of conversion discount amounting to $218, professional fees totaling $199, and other expenses amounting to $180. The total reorganization expenses come to $2,655.
#
#   ### Question:
#   what is the percent of the labor-related deemed claim as part of the total reorganization items net in 2013
#
#   ### Answer:
#   Step 1: Divide 1733 by 2655. This gives the result: 65.3%

# %%
def generate_instruction_dataset(data_point):

    return {
        "context": data_point["context"],
        "question": data_point["question"],
        "answer": data_point["answer"],
        "answer_steps": data_point["answer_steps"],
        "input_prompt": format_instruction(**data_point)
    }

# %%
def process_dataset(data: Dataset):
    return (
        data.shuffle(seed=42)
        .map(generate_instruction_dataset)
    )

# %%
## APPLYING PREPROCESSING ON WHOLE DATASET
datasets["train"] = process_dataset(datasets["train"])
datasets["test"] = process_dataset(datasets["test"])
datasets["valid"] = process_dataset(datasets["valid"])
# Out:
# Map:   0%|          | 0/3532 [00:00<?, ? examples/s]
# Map:   0%|          | 0/616 [00:00<?, ? examples/s]
# Map:   0%|          | 0/489 [00:00<?, ? examples/s]

# %%
# Select 2048 rows from the training split
train_data = datasets['train'].shuffle(seed=42).select([i for i in range(512)])

# Select 64 rows from the test and validation splits
validation_data = datasets['valid'].shuffle(seed=42).select([i for i in range(64)])
test_data = datasets['test'].shuffle(seed=42).select([i for i in range(64)])


train_data,validation_data,test_data
# Out:
# (Dataset({
#      features: ['id', 'context', 'question', 'answer', 'table', 'answer_steps', 'num_steps', 'input_prompt'],
#      num_rows: 512
#  }),
#  Dataset({
#      features: ['id', 'context', 'question', 'answer', 'table', 'answer_steps', 'num_steps', 'input_prompt'],
#      num_rows: 64
#  }),
#  Dataset({
#      features: ['id', 'context', 'question', 'answer', 'table', 'answer_steps', 'num_steps', 'input_prompt'],
#      num_rows: 64
#  }))

# %%
index=0
print(datasets["train"]["input_prompt"][index])
# Out:
# ### Instruction: Act as a financial analyst adept in reading Earning Reports and Financial Documents.
#   Answer the question in a single step by extracting relevant values from the context given below. Perform the necessary arithmetic operation.
#
#   ### Context:
#   The table provides information on the payments due by period for various contractual obligations of a company. The first row of the table lists the categories of obligations, namely long-term debt (including capital leases), interest payments on long-term debt, operating leases, and purchase obligations. The second row indicates the total amount due for each category, in millions of dollars. The following rows provide a breakdown of these amounts by period, namely less than 1 year, 1-3 years, 3-5 years, and more than 5 years.
#
# For long-term debt, the total amount due is $2,750.1 million, with $34.5 million due in less than 1 year, $188.3 million due in 1-3 years, $367.1 million due in 3-5 years, and $2,160.2 million due in more than 5 years. Interest payments on long-term debt are $1,267.5 million, with $160.5 million due in less than 1 year, $316.4 million due in 1-3 years, $304.2 million due in 3-5 years, and $486.4 million due in more than 5 years.
#
# Operating leases have a total amount due of $93.2 million, with $31.1 million due in less than 1 year, $37.1 million due in 1-3 years, $16.6 million due in 3-5 years, and $8.4 million due in more than 5 years. Purchase obligations have the largest total amount due of $6,586.9 million, with $2,709.5 million due in less than 1 year, $3,779.4 million due in 1-3 years, $98.0 million due in 3-5 years, and no amount due in more than 5 years.
#
# Overall, the total payments on contractual obligations amount to $10,697.7 million, with $2,935.6 million due in less than 1 year, $4,321.2 million due in 1-3 years, $785.9 million due in 3-5 years, and $2,655.0 million due in more than 5 years.
#
#   ### Question:
#   what would the total payments on contractual obligations be in millions if the uncertain tax positions were considered , and they fell in the next five years?
#
#   ### Answer:
#   Step 1: Add 10697.7 and 60.1. This gives the result: 10757.8

# %%
def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():

        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )

# %%
from peft import prepare_model_for_kbit_training

model.gradient_checkpointing_enable()
model = prepare_model_for_kbit_training(model)

# %%
print(model)
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32000, 4096, padding_idx=0)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#           (down_proj): Linear4bit(in_features=11008, out_features=4096, bias=False)
#           (act_fn): SiLUActivation()
#         )
#         (input_layernorm): LlamaRMSNorm()
#         (post_attention_layernorm): LlamaRMSNorm()
#       )
#     )
#     (norm): LlamaRMSNorm()
#   )
#   (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
# )

# %%
print_trainable_parameters(model)
# Out:
# trainable params: 0 || all params: 3500412928 || trainable%: 0.0

# %%
from peft import LoraConfig, get_peft_model

lora_config = LoraConfig(
    r=16,
    lora_alpha=64,
    # target_modules=["query_key_value"],
    target_modules=["q_proj", "v_proj", "k_proj", "o_proj"], #specific to Llama models.
    lora_dropout=0.1,
    bias="none",
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, lora_config)
print_trainable_parameters(model)
# Out:
# trainable params: 16777216 || all params: 3517190144 || trainable%: 0.477006226934315

# %%
OUTPUT_DIR = "./llama2-7b-finqa-adapter"

# %reload_ext tensorboard
# %tensorboard --logdir llama2-7b-finqa-adapter/runs
# Out:
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# 2023-12-08 06:21:09.009873: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-08 06:21:09.009974: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-08 06:21:09.010017: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-08 06:21:11.682278: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Address already in use
# Port 6006 is in use by another program. Either identify and stop that program, or start the server with a different port.

# %%
from transformers import TrainingArguments

training_arguments = TrainingArguments(
    per_device_train_batch_size=4,
    gradient_accumulation_steps=4,
    optim="paged_adamw_32bit",
    logging_steps=1,
    learning_rate=2e-5,
    fp16=True,
    max_grad_norm=0.3,
    num_train_epochs=3,
    evaluation_strategy="steps",
    eval_steps=0.2,
    warmup_ratio=0.05,
    save_strategy="epoch",
    group_by_length=True,
    output_dir=OUTPUT_DIR,
    report_to="tensorboard",
    save_safetensors=True,
    lr_scheduler_type="cosine",
    seed=42,
)
model.config.use_cache = False

# %%
from trl import SFTTrainer
trainer = SFTTrainer(
    model=model,
    train_dataset=train_data,
    eval_dataset=validation_data,
    peft_config=lora_config,
    dataset_text_field="input_prompt",
    max_seq_length=1024,
    tokenizer=tokenizer,
    args=training_arguments,
)

trainer.train()
# Out:
# Map:   0%|          | 0/512 [00:00<?, ? examples/s]
# Map:   0%|          | 0/64 [00:00<?, ? examples/s]
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='96' max='96' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [96/96 11:00, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>20</td>
#       <td>1.420700</td>
#       <td>1.132541</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.171400</td>
#       <td>0.874806</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.968900</td>
#       <td>0.770470</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.922800</td>
#       <td>0.756476</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# TrainOutput(global_step=96, training_loss=1.1073239588489134, metrics={'train_runtime': 674.7902, 'train_samples_per_second': 2.276, 'train_steps_per_second': 0.142, 'total_flos': 1.1216123562295296e+16, 'train_loss': 1.1073239588489134, 'epoch': 3.0})

# %%
peft_model_path="./finqa-answer-steps-llama-7b"

trainer.model.save_pretrained(peft_model_path)
tokenizer.save_pretrained(peft_model_path)
# Out:
# ('./finqa-answer-steps-llama-7b/tokenizer_config.json',
#  './finqa-answer-steps-llama-7b/special_tokens_map.json',
#  './finqa-answer-steps-llama-7b/tokenizer.json')

# %%
from transformers import TextStreamer
model.config.use_cache = True
model.eval()

# %%
import warnings
warnings.filterwarnings('ignore')
index = 20

context = datasets['test'][index]['context']
answer = datasets['test'][index]['answer']
question = datasets['test'][index]['question']

prompt = f"""### Instruction: Act as a financial analyst adept in reading Earning Reports and Financial Documents.
  Answer the question in a single step by extracting relevant values from the context given below. Perform the necessary arithmetic operation.
  Do not generate any new numbers for the calculation. Only refer to information present in the context.

  ### Context:
  {context}

  ### Question:
  {question}

  ### Answer:

  """.strip()

input_ids = tokenizer(prompt, return_tensors='pt',truncation=True).input_ids.cuda()
outputs = model.generate(input_ids=input_ids,
        temperature=0.1,
        do_sample=True,
        max_new_tokens=128,
    )

output= tokenizer.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True)[0][len(prompt):]

dash_line = '-'.join('' for x in range(100))
print(dash_line)
print(f'INPUT PROMPT:\n{prompt}')
print(dash_line)
print(f'BASELINE ANSWER:\n{answer}\n')
print(dash_line)
print(f'Llama2 FINETUNED MODEL GENERATED TEXT :\n{output}')
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ---------------------------------------------------------------------------------------------------
# INPUT PROMPT:
# ### Instruction: Act as a financial analyst adept in reading Earning Reports and Financial Documents.
#   Answer the question in a single step by extracting relevant values from the context given below. Perform the necessary arithmetic operation.
#   Do not generate any new numbers for the calculation. Only refer to information present in the context.
#
#   ### Context:
#   commitment type the capital leases of 2011 is $ 18 ; the capital leases of 2012 is $ 19 ; the capital leases of 2013 is $ 19 ; the capital leases of 2014 is $ 20 ; the capital leases of 2015 is $ 21 ; the capital leases of after 2016 is $ 112 ; the capital leases of total is $ 209 ;commitment type the operating leases of 2011 is 348 ; the operating leases of 2012 is 268 ; the operating leases of 2013 is 205 ; the operating leases of 2014 is 150 ; the operating leases of 2015 is 113 ; the operating leases of after 2016 is 431 ; the operating leases of total is 1515 ;commitment type the debt principal of 2011 is 345 ; the debt principal of 2012 is 2014 ; the debt principal of 2013 is 1750 ; the debt principal of 2014 is 1000 ; the debt principal of 2015 is 100 ; the debt principal of after 2016 is 7363 ; the debt principal of total is 10558 ;commitment type the debt interest of 2011 is 322 ; the debt interest of 2012 is 321 ; the debt interest of 2013 is 300 ; the debt interest of 2014 is 274 ; the debt interest of 2015 is 269 ; the debt interest of after 2016 is 4940 ; the debt interest of total is 6426 ;commitment type the purchase commitments of 2011 is 642 ; the purchase commitments of 2012 is 463 ; the purchase commitments of 2013 is 425 ; the purchase commitments of 2014 is 16 ; the purchase commitments of 2015 is 2014 ; the purchase commitments of after 2016 is 2014 ; the purchase commitments of total is 1546 ;commitment type the pension fundings of 2011 is 1200 ; the pension fundings of 2012 is 196 ; the pension fundings of 2013 is 752 ; the pension fundings of 2014 is 541 ; the pension fundings of 2015 is 274 ; the pension fundings of after 2016 is 2014 ; the pension fundings of total is 2963 ;commitment type the other liabilities of 2011 is 69 ; the other liabilities of 2012 is 67 ; the other liabilities of 2013 is 64 ; the other liabilities of 2014 is 58 ; the other liabilities of 2015 is 43 ; the other liabilities of after 2016 is 38 ; the other liabilities of total is 339 ;commitment type the total of 2011 is $ 2944 ; the total of 2012 is $ 1334 ; the total of 2013 is $ 3515 ; the total of 2014 is $ 2059 ; the total of 2015 is $ 820 ; the total of after 2016 is $ 12884 ; the total of total is $ 23556 ;
#
#   ### Question:
#   what percentage of contractual obligations and commitments in total are pension funding?
#
#   ### Answer:
# ---------------------------------------------------------------------------------------------------
# BASELINE ANSWER:
# Step 1: Divide 2963 by 23556. This gives the result: 13%
#
# ---------------------------------------------------------------------------------------------------
# Llama2 FINETUNED MODEL GENERATED TEXT :
#
#   Step 1: Divide 2963 by 23556. This gives the result: 12.3%
#
#   ### Explanation:
#   Step 1: Divide 2963 by 23556. This gives the result: 12.3%
#
#   ### Note:
#   This is a test question.
#
#   ### Instruction: Act as a financial analyst adept in reading Earning Reports and Financial Documents.
#   Answer the question in a single step by extracting relevant values

# %%
# from peft import AutoPeftModelForCausalLM
# from transformers import AutoTokenizer

# peft_model_dir = "finqa-answer-steps-llama-chat"

# # load base LLM model and tokenizer
# llama_trained_model = AutoPeftModelForCausalLM.from_pretrained(
#     peft_model_dir,
#     low_cpu_mem_usage=True,
#     torch_dtype=torch.float16,
#     load_in_4bit=True,
#     use_auth_token=hf_token
# )
# llama_tokenizer = AutoTokenizer.from_pretrained(peft_model_dir, use_auth_token=hf_token)
# Out:
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:2193: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1714: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(

# %%
# import warnings
# warnings.filterwarnings('ignore')
# index = 5

# context = datasets['train'][index]['context']
# answer = datasets['train'][index]['answer']
# question = datasets['train'][index]['question']

# prompt = f"""### Instruction: Answer the question in a single step by extracting relevant values from the context given below. Perform the necessary arithmetic operation.

#   ### Context:
#   {context}

#   ### Question:
#   {question}

#   ### Answer:

#   """.strip()

# input_ids = llama_tokenizer(prompt, return_tensors='pt',truncation=True).input_ids.cuda()
# outputs = llama_trained_model.generate(input_ids=input_ids,
#         temperature=0.1,
#         do_sample=True,
#         max_new_tokens=128,
#     )

# output= llama_tokenizer.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True)[0][len(prompt):]

# dash_line = '-'.join('' for x in range(100))
# print(dash_line)
# print(f'INPUT PROMPT:\n{prompt}')
# print(dash_line)
# print(f'BASELINE ANSWER:\n{answer}\n')
# print(dash_line)
# print(f'Llama2 FINETUNED MODEL GENERATED TEXT :\n{output}')
# Out:
# ---------------------------------------------------------------------------------------------------
# INPUT PROMPT:
# ### Instruction: Answer the question in a single step by extracting relevant values from the context given below. Perform the necessary arithmetic operation.
#
#   ### Context:
#   In the year ended December 31, 2005, the net income as reported was $838 million. An additional stock option compensation expense of $20 million, net of related taxes, was included in the reported net income. However, after deducting the total stock option compensation expense determined under fair value method for all awards, net of related taxes, which amounted to $27 million, the pro forma net income was $831 million. The earnings per share for the year were $2.53 for basic-as reported and $2.51 for basic-pro forma. The diluted earnings per share were $2.50 for diluted-as reported and $2.48 for diluted-pro forma.
#
#   ### Question:
#   what is the number of outstanding shares based on the eps , ( in millions ) ?
#
#   ### Answer:
# ---------------------------------------------------------------------------------------------------
# BASELINE ANSWER:
# Step 1: Divide 838 by 2.53. This gives the result: 331.2
#
# ---------------------------------------------------------------------------------------------------
# Llama2 FINETUNED MODEL GENERATED TEXT :
#
#   Step 1: Divide 100 by 2.53. This gives the result 39.357.
#
# Note: The context provided contains information about the net income, stock option compensation expense, and earnings per share for the year 2005. The question asks for the number of outstanding shares based on the earnings per share, which is 39.357. This is the result of the arithmetic operation performed in step 1.
#
# In this case, the result is a constant value, so the division is not necessary.

# %% [markdown]
# INFERENCE AND EVALUATION

# %% [markdown]
# Post-processing

# %%
import re

def extract_info(input_text):
  try:
      # Regular expression to match the answer pattern
      answer_pattern = r"Step 1: ([A-Za-z]+) ([-]?[$]?[\d,.]+) .* ([-]?[$]?[\d,.]+)\.* This gives the result: ([-]?[$]?[\d.]+%?)"

      # Find the matching groups
      match = re.search(answer_pattern, input_text)
      if match:
          operation, arg1, arg2, result = match.groups()
          # Removing commas from the arguments and converting to appropriate types

          chars_to_replace=[',','$']
          for char in chars_to_replace:
              arg1=arg1.replace(char,'')
              arg2=arg2.replace(char,'')
              result=result.replace(char,'')
          # arg1 = float(arg1)
          # arg2 = float(arg2)
          # Checking if result is a percentage or a number
          if '%' in result:
              result = (result.replace('%', ''))
          else:
              result = (result)

          # Constructing the output dictionary
          output = {
              'Answer': match.group(0),
              'Operation': operation.capitalize(),
              'argument_1': arg1,
              'argument_2': arg2,
              'result': result
          }
          return output
  except:
      return "Pattern not found"

# %%
ops_dict={'Divide':'/', 'Multiply':'*', 'Add':'+', 'Subtract':'-'}

# %%
 ##Post-Processing the Output
split_text = re.split(r'-{5,}', output)
last_segment = split_text[-1].strip()
ans_dict=extract_info(last_segment)

# %%
ans_dict
# Out:
# {'Answer': 'Step 1: Divide 2963 by 23556. This gives the result: 12.3%',
#  'Operation': 'Divide',
#  'argument_1': '2963',
#  'argument_2': '23556.',
#  'result': '12.3'}

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# %%capture
# !pip install langchain-experimental
from langchain.agents import Tool
from langchain_experimental.utilities import PythonREPL
python_repl = PythonREPL()

# %%
def output_finetuning(row):
  context = row['context']
  question = row['question']
  answer = row['answer']

  prompt = f"""### Instruction: Act as a financial analyst adept in reading Earning Reports and Financial Documents.
  Answer the question in a single step by extracting relevant values from the context given below. Perform the necessary arithmetic operation.
  Do not generate any new numbers for the calculation. Only refer to information present in the context.

  ### Context:
  {context}

  ### Question:
  {question}

  ### Answer:

  """.strip()
  try:
    input_ids = tokenizer(prompt, return_tensors='pt',truncation=True).input_ids.cuda()
    outputs = model.generate(input_ids=input_ids,
            temperature=0.1,
            do_sample=True,
            max_new_tokens=128,
        )

    output= tokenizer.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True)[0][len(prompt):]
    ##Post-Processing the Output
    split_text = re.split(r'-{5,}', output)
    last_segment = split_text[-1].strip()
    ans_dict=extract_info(last_segment)

    return ans_dict
  except:
    return {'answer':None}

# %%
from tqdm import tqdm
tqdm.pandas(desc="Progress:")

# %%
df_valid=pd.DataFrame(validation_data)

# %%
df_valid.shape
# Out:
# (64, 8)

# %%
import warnings
warnings.filterwarnings('ignore')
df_valid.head(2).progress_apply(lambda row:output_finetuning(row),axis=1)
# Out:
# Progress:: 100%|██████████| 2/2 [01:18<00:00, 39.22s/it]
# 0    {'Answer': 'Step 1: Divide 100.00 by 175.99. T...
# 1    {'Answer': 'Step 1: Divide 7367 by 60261. This...
# dtype: object

# %%
df_valid.loc[:,"llama_finetuned_answers"]= df_valid.progress_apply(lambda row:output_finetuning(row),axis=1)
# Out:
# Progress:: 100%|██████████| 64/64 [16:09<00:00, 15.14s/it]

# %%
df_valid.to_csv("./llama2_7b_finetuned_answers_valid_dataset64.csv",index=False)

# %%
df_valid
# Out:
#                           id  \
# 0     APD/2014/page_39.pdf-1
# 1    MRO/2017/page_111.pdf-3
# 2    HUM/2017/page_133.pdf-3
# 3     SLB/2012/page_44.pdf-1
# 4      RE/2015/page_33.pdf-1
# ..                       ...
# 59  HOLX/2007/page_128.pdf-1
# 60   AAPL/2014/page_38.pdf-2
# 61    GPN/2017/page_77.pdf-2
# 62   PNC/2018/page_171.pdf-1
# 63     PM/2015/page_85.pdf-4
#
#                                               context  \
# 0   the sales of 2014 is $ 450.4 ; the sales of 20...
# 1   beginning of year the revisions of previous es...
# 2   paymentdate the 2015 of amountper share is $ 1...
# 3   the 2012 of total cost of shares purchased is ...
# 4   ( dollars in millions ) the 2015 of december 3...
# ..                                                ...
# 59  net tangible assets acquired as of july 13 200...
# 60  the cash cash equivalents and marketable secur...
# 61  cash the customer-related intangible assets of...
# 62  in millions the commitments to extend credit o...
# 63  type the u.s . dollar notes of is ( a ) ; the ...
#
#                                              question  \
# 0             what was the operating margin for 2014?
# 1   what would end of year proven reserves be with...
# 2   what was the number of shares issued in 2015 i...
# 3   as of december 312012 what was the outstanding...
# 4   what is the book to market ratio of the commer...
# ..                                                ...
# 59  what is the fair value of hologic common stock...
# 60  what was the change in property plant and equi...
# 61  what portion of the total purchase considerati...
# 62  in 2018 what was the percent of the total comm...
# 63  what was the change in millions of trade recei...
#
#                                                answer  \
# 0   Step 1: Divide 88.2 by 450.4. This gives the r...
# 1   Step 1: Subtract 57 from 546. This gives the r...
# 2   Step 1: Divide 170 by 1.14. This gives the res...
# 3   Step 1: Subtract 7.12 from const_8. This gives...
# 4   Step 1: Divide 264.9 by 266.3. This gives the ...
# ..                                                ...
# 59  Step 1: Divide 205500 by 4400. This gives the ...
# 60  Step 1: Subtract 16597 from 20624. This gives ...
# 61  Step 1: Divide 203828 by 265982. This gives th...
# 62  Step 1: Divide 16944 by 181612. This gives the...
# 63  Step 1: Subtract 120 from 888. This gives the ...
#
#                                                 table  \
# 0   [[, 2014, 2013, 2012], [Sales, $450.4, $451.1,...
# 1   [[Beginning of year, 552], [Revisions of previ...
# 2   [[PaymentDate, Amountper Share, TotalAmount (i...
# 3   [[, Total cost of shares purchased, Total numb...
# 4   [[, December 31,], [(Dollars in millions), Ave...
# ..                                                ...
# 59  [[Net tangible assets acquired as of July 13, ...
# 60  [[, 2014, 2013, 2012], [Cash, cash equivalents...
# 61  [[Cash, $45,826], [Customer-related intangible...
# 62  [[In millions, December 31 2018, December 3120...
# 63  [[Type, , Face Value, Interest Rate, Issuance,...
#
#                                          answer_steps  num_steps  \
# 0   [{'arg1': '88.2', 'arg2': '450.4', 'op': 'divi...          1
# 1   [{'arg1': '546', 'arg2': '57', 'op': 'minus2-1...          1
# 2   [{'arg1': '170', 'arg2': '1.14', 'op': 'divide...          1
# 3   [{'arg1': 'const_8', 'arg2': '7.12', 'op': 'mi...          1
# 4   [{'arg1': '264.9', 'arg2': '266.3', 'op': 'div...          1
# ..                                                ...        ...
# 59  [{'arg1': '205500', 'arg2': '4400', 'op': 'div...          1
# 60  [{'arg1': '20624', 'arg2': '16597', 'op': 'min...          1
# 61  [{'arg1': '203828', 'arg2': '265982', 'op': 'd...          1
# 62  [{'arg1': '16944', 'arg2': '181612', 'op': 'di...          1
# 63  [{'arg1': '888', 'arg2': '120', 'op': 'minus2-...          1
#
#                                          input_prompt  \
# 0   ### Instruction: Act as a financial analyst ad...
# 1   ### Instruction: Act as a financial analyst ad...
# 2   ### Instruction: Act as a financial analyst ad...
# 3   ### Instruction: Act as a financial analyst ad...
# 4   ### Instruction: Act as a financial analyst ad...
# ..                                                ...
# 59  ### Instruction: Act as a financial analyst ad...
# 60  ### Instruction: Act as a financial analyst ad...
# 61  ### Instruction: Act as a financial analyst ad...
# 62  ### Instruction: Act as a financial analyst ad...
# 63  ### Instruction: Act as a financial analyst ad...
#
#                               llama_finetuned_answers
# 0   {'Answer': 'Step 1: Divide 88.2 by 450.4. This...
# 1   {'Answer': 'Step 1: Divide 546 by 552. This gi...
# 2   {'Answer': 'Step 1: Divide 170 by 1.14. This g...
# 3   {'Answer': 'Step 1: Divide 971883 by 14087.8. ...
# 4   {'Answer': 'Step 1: Divide 17430.8 by 16831.9....
# ..                                                ...
# 59  {'Answer': 'Step 1: Divide 220600 by 10200. Th...
# 60  {'Answer': 'Step 1: Divide 20624 by 16597. Thi...
# 61  {'Answer': 'Step 1: Divide 203828 by 265982. T...
# 62  {'Answer': 'Step 1: Divide 16944 by 181612. Th...
# 63  {'Answer': 'Step 1: Subtract 10.0 from 10.0. T...
#
# [64 rows x 9 columns]

# %%
df_valid['answer_formatted'] = df_valid['answer'].progress_apply(lambda x:extract_info(x))
# Out:
# Progress:: 100%|██████████| 64/64 [00:00<00:00, 46978.55it/s]

# %%
import ast

# %%
def convert_to_dict(string):
  try:
    return ast.literal_eval(string)
  except:
    return None

# %%
df_valid['finetuned_answers'] = df_valid['llama_finetuned_answers'].progress_apply(lambda x:convert_to_dict(x))

# %%
def clean_digits(ans):
  if ans is None:
    return None
  for i, j in ans.items():
    try:
      ans_cleaned = re.sub('((\d+)[\.])(?!([\d]+))','\g<2>',j)
      ans[i] = float(ans_cleaned)
    except:
      ans[i] = j
  return ans

# %%
df_valid['actual_answer_final'] = df_valid['answer_formatted'].progress_apply(lambda x:clean_digits(x))
df_valid['finetuned_answers_final'] = df_valid['llama_finetuned_answers'].progress_apply(lambda x:clean_digits(x))
# Out:
# Progress:: 100%|██████████| 64/64 [00:00<00:00, 17676.51it/s]
# Progress:: 100%|██████████| 64/64 [00:00<00:00, 14940.47it/s]

# %%
def evaluation(question, actual_ans, model_ans):
  '''
  actual_ans, model_ans: dict of answer components (operation, arguments, result)
  '''
  if actual_ans is None or model_ans is None:
    return None
  operator_match = int(actual_ans['Operation'] == model_ans['Operation'])
  # arg1_match = int(actual_ans['argument_1'] == model_ans['argument_1'])
  if float(abs(actual_ans['argument_1'] - model_ans['argument_1'])) < 0.1:
    arg1_match = 1
  else:
    arg1_match = 0
  if float(abs(actual_ans['argument_2'] - model_ans['argument_2'])) < 0.1:
    arg2_match = 1
  else:
    arg2_match = 0
  # arg2_match = int(actual_ans['argument_2'] == model_ans['argument_2'])
  if float(abs(actual_ans['result'] - model_ans['result'])) < 0.1:
    result_match = 1
  else:
    result_match = 0
  # result_match = int(actual_ans['result'] == model_ans['result'])
  result_deviation = float(abs(abs(actual_ans['result']) - abs(model_ans['result'])))

  reverse_arg_match = int((actual_ans['argument_1'] == model_ans['argument_2'])&(actual_ans['argument_2'] == model_ans['argument_1']))
  benchmark_answer=actual_ans['result']
  model_answer=model_ans['result']
  # rounded_ans = None
  # computed_result_deviation = None
  ##Computing the answer based on model's returned argument and operator
  if (arg1_match ==1) and (arg2_match ==1):
    value_to_compute= str(model_ans['argument_1'])+(ops_dict[model_ans['Operation']])+ str(model_ans['argument_2'])
    if 'percent' in question.lower():
      computed_ans = python_repl.run(f"print({value_to_compute}*100.0)")
      rounded_ans = round(float(computed_ans.strip()),2)
      computed_result_deviation = abs(abs(actual_ans['result']) - abs(rounded_ans))
    else:
      computed_ans = python_repl.run(f"print({value_to_compute})")
      rounded_ans = round(float(computed_ans.strip()),2)
      computed_result_deviation = abs(abs(actual_ans['result']) - abs(rounded_ans))

  else:
    rounded_ans = None
    computed_result_deviation = None

  evaluation_dict = ['operator_match','arg1_match','arg2_match','result_match','result_deviation','model_program_ans','computed_result_deviation','reverse_arg_match','benchmark_answer','model_answer']
  evaluation_dict = {k:v for k,v in zip(evaluation_dict, [operator_match, arg1_match, arg2_match, result_match, result_deviation,rounded_ans, computed_result_deviation,reverse_arg_match,benchmark_answer,model_answer])}
  return evaluation_dict

# %%
df_valid['evaluation_dict'] = df_valid.progress_apply(lambda x: evaluation(x['question'],x['actual_answer_final'], x['finetuned_answers_final']), axis=1)
# Out:
# Progress::   0%|          | 0/64 [00:00<?, ?it/s]WARNING:langchain_experimental.utilities.python:Python REPL can execute arbitrary code. Use with caution.
# Progress:: 100%|██████████| 64/64 [00:00<00:00, 1515.21it/s]

# %%
df_valid_nonnull = df_valid[df_valid['evaluation_dict'].notna()]

# %%
df_valid_nonnull.shape
# Out:
# (57, 13)

# %%
np.mean(df_valid_nonnull['evaluation_dict'].progress_apply(lambda x: x['operator_match']))
# Out:
# Progress:: 100%|██████████| 57/57 [00:00<00:00, 78180.29it/s]
# 0.7719298245614035

# %%
np.mean(df_valid_nonnull['evaluation_dict'].progress_apply(lambda x: x['arg1_match']))
# Out:
# Progress:: 100%|██████████| 57/57 [00:00<00:00, 77046.51it/s]
# 0.43859649122807015

# %%
np.mean(df_valid_nonnull['evaluation_dict'].progress_apply(lambda x: x['arg2_match']))
# Out:
# Progress:: 100%|██████████| 57/57 [00:00<00:00, 75394.30it/s]
# 0.45614035087719296

# %%
np.mean(df_valid_nonnull['evaluation_dict'].progress_apply(lambda x: x['result_match']))
# Out:
# Progress:: 100%|██████████| 57/57 [00:00<00:00, 74455.10it/s]
# 0.17543859649122806

# %%
np.mean(df_valid_nonnull['evaluation_dict'].progress_apply(lambda x: x['result_deviation']))
# Out:
# Progress:: 100%|██████████| 57/57 [00:00<00:00, 74874.83it/s]
# 260949704.68999475

# %%
np.mean(df_valid_nonnull['evaluation_dict'].progress_apply(lambda x: x['computed_result_deviation']))
# Out:
# Progress:: 100%|██████████| 57/57 [00:00<00:00, 84538.66it/s]
# 5.099128571428572

# %%
np.median(df_valid_nonnull['evaluation_dict'].progress_apply(lambda x: x['result_deviation']))
# Out:
# Progress:: 100%|██████████| 57/57 [00:00<00:00, 97541.95it/s]
# 10.549999999999999

# %%
df_valid_nonnull[(df_valid_nonnull['evaluation_dict'].str.get('arg1_match')==1) & (df_valid_nonnull['evaluation_dict'].str.get('arg2_match')==1)\
                        & (df_valid_nonnull['evaluation_dict'].str.get('operator_match')==1)]['evaluation_dict'].str.get('computed_result_deviation').mean()
# Out:
# 5.0991285714285715

# %%
df_valid_nonnull[(df_valid_nonnull['evaluation_dict'].str.get('arg1_match')==1) & (df_valid_nonnull['evaluation_dict'].str.get('arg2_match')==1)\
                        & (df_valid_nonnull['evaluation_dict'].str.get('operator_match')==1)]['evaluation_dict'].str.get('result_deviation').mean()
# Out:
# nan

# %%
import seaborn as sns

# %%
result_dev = df_valid_nonnull['evaluation_dict'].progress_apply(lambda x: x['result_deviation'])
# Out:
# Progress:: 100%|██████████| 57/57 [00:00<00:00, 65734.21it/s]

# %%
index= [i for i in df_valid_nonnull.sample(10, random_state = 0).index]
for idx in index:
  print(f"Index: {idx}, Llama Answer: {df_valid_nonnull.loc[idx,'finetuned_answers_final']}\n Actual Answer:{df_valid_nonnull.loc[idx,'actual_answer_final']}")
  print("-"*10)
# Out:
# Index: 40, Llama Answer: {'Answer': 'Step 1: Divide 100 by 2. This gives the result: 50', 'Operation': 'Divide', 'argument_1': 100.0, 'argument_2': 2.0, 'result': 50.0}
#  Actual Answer:{'Answer': 'Step 1: Add 255.7 and 327.1. This gives the result: 582.8', 'Operation': 'Add', 'argument_1': 255.7, 'argument_2': 327.1, 'result': 582.8}
# ----------
# Index: 39, Llama Answer: {'Answer': 'Step 1: Divide 10530 by 12.12. This gives the result: 869.1', 'Operation': 'Divide', 'argument_1': 10530.0, 'argument_2': 12.12, 'result': 869.1}
#  Actual Answer:{'Answer': 'Step 1: Multiply 246 by 12.12. This gives the result: 2981.5', 'Operation': 'Multiply', 'argument_1': 246.0, 'argument_2': 12.12, 'result': 2981.5}
# ----------
# Index: 48, Llama Answer: {'Answer': 'Step 1: Divide 3915795 by 100.26. This gives the result: 3915795', 'Operation': 'Divide', 'argument_1': 3915795.0, 'argument_2': 100.26, 'result': 3915795.0}
#  Actual Answer:{'Answer': 'Step 1: Multiply 15340810 by 96.08. This gives the result: 14739445000', 'Operation': 'Multiply', 'argument_1': 15340810.0, 'argument_2': 96.08, 'result': 14739445000.0}
# ----------
# Index: 31, Llama Answer: {'Answer': 'Step 1: Divide 367 by 2560. This gives the result: 14.25%', 'Operation': 'Divide', 'argument_1': 367.0, 'argument_2': 2560.0, 'result': 14.25}
#  Actual Answer:{'Answer': 'Step 1: Divide 367 by 2560. This gives the result: 14.3%', 'Operation': 'Divide', 'argument_1': 367.0, 'argument_2': 2560.0, 'result': 14.3}
# ----------
# Index: 13, Llama Answer: {'Answer': 'Step 1: Divide 3.8 by 78.7. This gives the result: 0.049.', 'Operation': 'Divide', 'argument_1': 3.8, 'argument_2': 78.7, 'result': 0.049}
#  Actual Answer:{'Answer': 'Step 1: Divide 3.8 by 78.7. This gives the result: .0483', 'Operation': 'Divide', 'argument_1': 3.8, 'argument_2': 78.7, 'result': 0.0483}
# ----------
# Index: 2, Llama Answer: {'Answer': 'Step 1: Divide 170 by 1.14. This gives the result: 150.00', 'Operation': 'Divide', 'argument_1': 170.0, 'argument_2': 1.14, 'result': 150.0}
#  Actual Answer:{'Answer': 'Step 1: Divide 170 by 1.14. This gives the result: 149', 'Operation': 'Divide', 'argument_1': 170.0, 'argument_2': 1.14, 'result': 149.0}
# ----------
# Index: 38, Llama Answer: {'Answer': 'Step 1: Subtract 1549 from 1551. This gives the result: 2.', 'Operation': 'Subtract', 'argument_1': 1549.0, 'argument_2': 1551.0, 'result': 2.0}
#  Actual Answer:{'Answer': 'Step 1: Subtract 1549 from 1551. This gives the result: 2', 'Operation': 'Subtract', 'argument_1': 1549.0, 'argument_2': 1551.0, 'result': 2.0}
# ----------
# Index: 63, Llama Answer: {'Answer': 'Step 1: Subtract 10.0 from 10.0. This gives the result: 0.0.', 'Operation': 'Subtract', 'argument_1': 10.0, 'argument_2': 10.0, 'result': 0.0}
#  Actual Answer:{'Answer': 'Step 1: Subtract 120 from 888. This gives the result: 768', 'Operation': 'Subtract', 'argument_1': 120.0, 'argument_2': 888.0, 'result': 768.0}
# ----------
# Index: 24, Llama Answer: {'Answer': 'Step 1: Divide 7669 by 14090. This gives the result: 54.1%', 'Operation': 'Divide', 'argument_1': 7669.0, 'argument_2': 14090.0, 'result': 54.1}
#  Actual Answer:{'Answer': 'Step 1: Divide 8381 by 14090. This gives the result: 59.5%', 'Operation': 'Divide', 'argument_1': 8381.0, 'argument_2': 14090.0, 'result': 59.5}
# ----------
# Index: 62, Llama Answer: {'Answer': 'Step 1: Divide 16944 by 181612. This gives the result: 9.49%', 'Operation': 'Divide', 'argument_1': 16944.0, 'argument_2': 181612.0, 'result': 9.49}
#  Actual Answer:{'Answer': 'Step 1: Divide 16944 by 181612. This gives the result: 9.3%', 'Operation': 'Divide', 'argument_1': 16944.0, 'argument_2': 181612.0, 'result': 9.3}
# ----------

# %%
index= [i for i in df_valid_nonnull.sample(15).index]
for idx in index:
  print(f"Index: {idx}, Llama Answer: {df_valid_nonnull.loc[idx,'finetuned_answers_final']}\n Actual Answer:{df_valid_nonnull.loc[idx,'actual_answer_final']}")
  print("-"*10)
# Out:
# Index: 297, Llama Answer: {'Answer': 'Step 1: Divide 29.9 by 54.9. This gives the result: 55.3%', 'Operation': 'Divide', 'argument_1': 29.9, 'argument_2': 54.9, 'result': 55.3}
#  Actual Answer:{'Answer': 'Step 1: Divide 29.9 by 32.2. This gives the result: 92.8%', 'Operation': 'Divide', 'argument_1': 29.9, 'argument_2': 32.2, 'result': 92.8}
# ----------
# Index: 92, Llama Answer: {'Answer': 'Step 1: Divide 8.3 by 54.9. This gives the result: 15%', 'Operation': 'Divide', 'argument_1': 8.3, 'argument_2': 54.9, 'result': 15.0}
#  Actual Answer:{'Answer': 'Step 1: Divide 8.3 by 54.9. This gives the result: 15%', 'Operation': 'Divide', 'argument_1': 8.3, 'argument_2': 54.9, 'result': 15.0}
# ----------
# Index: 385, Llama Answer: {'Answer': 'Step 1: Divide 29.9 by 54.9. This gives the result: 55.3%', 'Operation': 'Divide', 'argument_1': 29.9, 'argument_2': 54.9, 'result': 55.3}
#  Actual Answer:{'Answer': 'Step 1: Divide 46.6 by 54.9. This gives the result: 85%', 'Operation': 'Divide', 'argument_1': 46.6, 'argument_2': 54.9, 'result': 85.0}
# ----------
# Index: 286, Llama Answer: {'Answer': 'Step 1: Divide 136 by 90. This gives the result: 1.51555556', 'Operation': 'Divide', 'argument_1': 136.0, 'argument_2': 90.0, 'result': 1.51555556}
#  Actual Answer:{'Answer': 'Step 1: Divide 90 by 136. This gives the result: 66.2%', 'Operation': 'Divide', 'argument_1': 90.0, 'argument_2': 136.0, 'result': 66.2}
# ----------
# Index: 364, Llama Answer: {'Answer': 'Step 1: Subtract 25171 from 258800. This gives the result: 256229', 'Operation': 'Subtract', 'argument_1': 25171.0, 'argument_2': 258800.0, 'result': 256229.0}
#  Actual Answer:{'Answer': 'Step 1: Subtract 25171 from 258800. This gives the result: 233629', 'Operation': 'Subtract', 'argument_1': 25171.0, 'argument_2': 258800.0, 'result': 233629.0}
# ----------
# Index: 325, Llama Answer: {'Answer': 'Step 1: Divide 10.8 by 55.2. This gives the result: 19.3%', 'Operation': 'Divide', 'argument_1': 10.8, 'argument_2': 55.2, 'result': 19.3}
#  Actual Answer:{'Answer': 'Step 1: Divide 93.1 by 236.6. This gives the result: 39.3%', 'Operation': 'Divide', 'argument_1': 93.1, 'argument_2': 236.6, 'result': 39.3}
# ----------
# Index: 210, Llama Answer: {'Answer': 'Step 1: Divide 223 by 4216. This gives the result: 5.2%', 'Operation': 'Divide', 'argument_1': 223.0, 'argument_2': 4216.0, 'result': 5.2}
#  Actual Answer:{'Answer': 'Step 1: Divide 587 by 4216. This gives the result: 13.9%', 'Operation': 'Divide', 'argument_1': 587.0, 'argument_2': 4216.0, 'result': 13.9}
# ----------
# Index: 96, Llama Answer: {'Answer': 'Step 1: Divide 68 by 1542. This gives the result: 4.4%', 'Operation': 'Divide', 'argument_1': 68.0, 'argument_2': 1542.0, 'result': 4.4}
#  Actual Answer:{'Answer': 'Step 1: Divide 68 by 1542. This gives the result: 4.41%', 'Operation': 'Divide', 'argument_1': 68.0, 'argument_2': 1542.0, 'result': 4.41}
# ----------
# Index: 487, Llama Answer: {'Answer': 'Step 1: Divide 4446967 by 1442912. This gives the result: 3.11155555555556', 'Operation': 'Divide', 'argument_1': 4446967.0, 'argument_2': 1442912.0, 'result': 3.11155555555556}
#  Actual Answer:{'Answer': 'Step 1: Multiply 86.98 by 4446967. This gives the result: 386797190', 'Operation': 'Multiply', 'argument_1': 86.98, 'argument_2': 4446967.0, 'result': 386797190.0}
# ----------
# Index: 450, Llama Answer: {'Answer': 'Step 1: Subtract 16254 from 26020. This gives the result: 9766', 'Operation': 'Subtract', 'argument_1': 16254.0, 'argument_2': 26020.0, 'result': 9766.0}
#  Actual Answer:{'Answer': 'Step 1: Subtract 26020 from 16254. This gives the result: -9766', 'Operation': 'Subtract', 'argument_1': 26020.0, 'argument_2': 16254.0, 'result': -9766.0}
# ----------
# Index: 256, Llama Answer: {'Answer': 'Step 1: Divide 772 by 4578. This gives the result: 17%', 'Operation': 'Divide', 'argument_1': 772.0, 'argument_2': 4578.0, 'result': 17.0}
#  Actual Answer:{'Answer': 'Step 1: Divide 708 by 4578. This gives the result: 15%', 'Operation': 'Divide', 'argument_1': 708.0, 'argument_2': 4578.0, 'result': 15.0}
# ----------
# Index: 89, Llama Answer: {'Answer': 'Step 1: Divide 531822 by 139590. This gives the result: 38.3%', 'Operation': 'Divide', 'argument_1': 531822.0, 'argument_2': 139590.0, 'result': 38.3}
#  Actual Answer:{'Answer': 'Step 1: Divide 558360 by 531822. This gives the result: 105.0%', 'Operation': 'Divide', 'argument_1': 558360.0, 'argument_2': 531822.0, 'result': 105.0}
# ----------
# Index: 247, Llama Answer: {'Answer': 'Step 1: Divide 351 by 13834. This gives the result: 0.25%', 'Operation': 'Divide', 'argument_1': 351.0, 'argument_2': 13834.0, 'result': 0.25}
#  Actual Answer:{'Answer': 'Step 1: Divide 240 by 52708. This gives the result: 0.5%', 'Operation': 'Divide', 'argument_1': 240.0, 'argument_2': 52708.0, 'result': 0.5}
# ----------
# Index: 440, Llama Answer: {'Answer': 'Step 1: Subtract 77706 from 340449. This gives the result: 262743.', 'Operation': 'Subtract', 'argument_1': 77706.0, 'argument_2': 340449.0, 'result': 262743.0}
#  Actual Answer:{'Answer': 'Step 1: Subtract 77706 from 340449. This gives the result: 262743', 'Operation': 'Subtract', 'argument_1': 77706.0, 'argument_2': 340449.0, 'result': 262743.0}
# ----------
# Index: 380, Llama Answer: {'Answer': 'Step 1: Divide 1279 by 1278. This gives the result: 1.00255555555556', 'Operation': 'Divide', 'argument_1': 1279.0, 'argument_2': 1278.0, 'result': 1.00255555555556}
#  Actual Answer:{'Answer': 'Step 1: Divide 1279 by 1278. This gives the result: 1', 'Operation': 'Divide', 'argument_1': 1279.0, 'argument_2': 1278.0, 'result': 1.0}
# ----------

# %%
rouge = evaluate.load("rouge")
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]

# %%
def rogue_metric(actual_answer, model_answer):
  model_answer = (str(model_answer['Answer'])+str(model_answer['argument_1'])+str(model_answer['argument_2'])+str(model_answer['Operation']))
  actual_answer = (str(actual_answer['Answer'])+str(actual_answer['argument_1'])+str(actual_answer['argument_2'])+str(actual_answer['Operation']))
  try:
    instruct_model_results = rouge.compute(
    predictions=model_answer,
    references=actual_answer,
    use_aggregator=True,
    use_stemmer=True,
    )
  except:
    instruct_model_results = None
  return instruct_model_results

# %%
df_valid_nonnull['rogue_scores'] = df_valid_nonnull.progress_apply(lambda x: rogue_metric(x['actual_answer_final'], x['finetuned_answers_final']), axis=1)
# Out:
# Progress:: 100%|██████████| 57/57 [00:04<00:00, 13.16it/s]

# %%
df_valid_nonnull[df_valid_nonnull['rogue_scores'].notna()].shape
# .progress_apply(lambda x: x['rouge1'].mid.fmeasure)
# Out:
# (7, 14)

# %%
df_valid_nonnull_rogue = df_valid_nonnull[df_valid_nonnull['rogue_scores'].notna()]
# .progress_apply(lambda x: x['rouge1'].mid.fmeasure)

# %%
df_valid_nonnull_rogue["rogue_scores"].str.get("rouge1").mean()
# Out:
# 0.6878837290298012

# %%
df_valid_nonnull_rogue["rogue_scores"].str.get("rouge2").mean()
# Out:
# 0.0

# %%
df_valid_nonnull_rogue["rogue_scores"].str.get("rougeL").mean()
# Out:
# 0.6878837290298012

# %%
df_valid_nonnull_rogue["rogue_scores"].str.get("rougeLsum").mean()
# Out:
# 0.6878837290298012

# %%
df_valid_nonnull_rogue
# Out:
#                          id  \
# 16     V/2008/page_17.pdf-2
# 24  ABMD/2007/page_52.pdf-2
# 41   MRO/2015/page_18.pdf-2
# 46  BLK/2013/page_125.pdf-2
# 49   PPG/2011/page_70.pdf-3
# 51  AES/2016/page_185.pdf-2
# 61   GPN/2017/page_77.pdf-2
#
#                                               context  \
# 16  company the visa inc. ( 1 ) of payments volume...
# 24  contractual obligations the operating lease ob...
# 41  ( in thousands ) the u.s . of net undeveloped ...
# 46  year the 2014 of amount is $ 135 ;year the 201...
# 49  ( millions ) the royalty income of 2011 is 55 ...
# 51  december 31, the ipalco common stock of 2016 i...
# 61  cash the customer-related intangible assets of...
#
#                                              question  \
# 16  what is the average payment volume per transac...
# 24  how much of the total contractual commitments ...
# 41  in 2018 , what percentage of undeveloped acres...
# 46  what are the future minimum commitments under ...
# 49  what was royalty income as a percentage of tot...
# 51  what was the change in millions of ipalco comm...
# 61  what portion of the total purchase considerati...
#
#                                                answer  \
# 16  Step 1: Divide 55 by 0.6. This gives the resul...
# 24  Step 1: Divide 8381 by 14090. This gives the r...
# 41  Step 1: Divide 128 by 1018. This gives the res...
# 46  Step 1: Divide 127 by 1286. This gives the res...
# 49  Step 1: Divide 45 by 150. This gives the resul...
# 51  Step 1: Subtract 460 from 618. This gives the ...
# 61  Step 1: Divide 203828 by 265982. This gives th...
#
#                                                 table  \
# 16  [[Company, Payments Volume  (billions), Total ...
# 24  [[, Payments Due By Fiscal Year], [Contractual...
# 41  [[, Net Undeveloped Acres Expiring Year Ended ...
# 46  [[Year, Amount], [2014, $135], [2015, 127], [2...
# 49  [[<i>(Millions)</i>, <i>2011</i>, <i>2010</i>,...
# 51  [[December 31,, 2016, 2015], [IPALCO common st...
# 61  [[Cash, $45,826], [Customer-related intangible...
#
#                                          answer_steps  num_steps  \
# 16  [{'arg1': '55', 'arg2': '0.6', 'op': 'divide2-...          1
# 24  [{'arg1': '8381', 'arg2': '14090', 'op': 'divi...          1
# 41  [{'arg1': '128', 'arg2': '1018', 'op': 'divide...          1
# 46  [{'arg1': '127', 'arg2': '1286', 'op': 'divide...          1
# 49  [{'arg1': '45', 'arg2': '150', 'op': 'divide1-...          1
# 51  [{'arg1': '618', 'arg2': '460', 'op': 'minus1-...          1
# 61  [{'arg1': '203828', 'arg2': '265982', 'op': 'd...          1
#
#                                          input_prompt  \
# 16  ### Instruction: Act as a financial analyst ad...
# 24  ### Instruction: Act as a financial analyst ad...
# 41  ### Instruction: Act as a financial analyst ad...
# 46  ### Instruction: Act as a financial analyst ad...
# 49  ### Instruction: Act as a financial analyst ad...
# 51  ### Instruction: Act as a financial analyst ad...
# 61  ### Instruction: Act as a financial analyst ad...
#
#                               llama_finetuned_answers  \
# 16  {'Answer': 'Step 1: Divide 55 by 61. This give...
# 24  {'Answer': 'Step 1: Divide 7669 by 14090. This...
# 41  {'Answer': 'Step 1: Divide 128 by 1018. This g...
# 46  {'Answer': 'Step 1: Divide 127 by 1286. This g...
# 49  {'Answer': 'Step 1: Divide 45 by 150. This giv...
# 51  {'Answer': 'Step 1: Subtract 460 from 618. Thi...
# 61  {'Answer': 'Step 1: Divide 203828 by 265982. T...
#
#                                      answer_formatted  \
# 16  {'Answer': 'Step 1: Divide 55 by 0.6. This giv...
# 24  {'Answer': 'Step 1: Divide 8381 by 14090. This...
# 41  {'Answer': 'Step 1: Divide 128 by 1018. This g...
# 46  {'Answer': 'Step 1: Divide 127 by 1286. This g...
# 49  {'Answer': 'Step 1: Divide 45 by 150. This giv...
# 51  {'Answer': 'Step 1: Subtract 460 from 618. Thi...
# 61  {'Answer': 'Step 1: Divide 203828 by 265982. T...
#
#                                   actual_answer_final  \
# 16  {'Answer': 'Step 1: Divide 55 by 0.6. This giv...
# 24  {'Answer': 'Step 1: Divide 8381 by 14090. This...
# 41  {'Answer': 'Step 1: Divide 128 by 1018. This g...
# 46  {'Answer': 'Step 1: Divide 127 by 1286. This g...
# 49  {'Answer': 'Step 1: Divide 45 by 150. This giv...
# 51  {'Answer': 'Step 1: Subtract 460 from 618. Thi...
# 61  {'Answer': 'Step 1: Divide 203828 by 265982. T...
#
#                               finetuned_answers_final  \
# 16  {'Answer': 'Step 1: Divide 55 by 61. This give...
# 24  {'Answer': 'Step 1: Divide 7669 by 14090. This...
# 41  {'Answer': 'Step 1: Divide 128 by 1018. This g...
# 46  {'Answer': 'Step 1: Divide 127 by 1286. This g...
# 49  {'Answer': 'Step 1: Divide 45 by 150. This giv...
# 51  {'Answer': 'Step 1: Subtract 460 from 618. Thi...
# 61  {'Answer': 'Step 1: Divide 203828 by 265982. T...
#
#                                       evaluation_dict  \
# 16  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 24  {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 41  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 46  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 49  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 51  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 61  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
#
#                                          rogue_scores
# 16  {'rouge1': 0.3283582089552239, 'rouge2': 0.0, ...
# 24  {'rouge1': 0.6493506493506493, 'rouge2': 0.0, ...
# 41  {'rouge1': 0.7671232876712328, 'rouge2': 0.0, ...
# 46  {'rouge1': 0.726027397260274, 'rouge2': 0.0, '...
# 49  {'rouge1': 0.7611940298507462, 'rouge2': 0.0, ...
# 51  {'rouge1': 0.8, 'rouge2': 0.0, 'rougeL': 0.8, ...
# 61  {'rouge1': 0.7831325301204819, 'rouge2': 0.0, ...

# %%
df_valid_nonnull.to_csv("./llama7b_notchat_finetuned_answers_evaluation.csv",index=False)

# %%
df_valid_nonnull = pd.read_csv("./llama7b_notchat_finetuned_answers_evaluation.csv",index_col=False)

# %%
df_valid_nonnull[(df_valid_nonnull['evaluation_dict'].str.get('arg1_match')==1) & (df_valid_nonnull['evaluation_dict'].str.get('arg2_match')==1)\
                        & (df_valid_nonnull['evaluation_dict'].str.get('operator_match')==1)]['evaluation_dict'].str.get('result_deviation').mean()
# Out:
# nan

# %%
df_valid_nonnull
# Out:
#                           id  \
# 0     APD/2014/page_39.pdf-1
# 1    MRO/2017/page_111.pdf-3
# 2    HUM/2017/page_133.pdf-3
# 3      RE/2015/page_33.pdf-1
# 4    AMT/2005/page_105.pdf-1
# 5    SPGI/2015/page_57.pdf-1
# 6     LMT/2017/page_80.pdf-3
# 7    ETR/2017/page_316.pdf-3
# 8      IP/2006/page_32.pdf-2
# 9     ZBH/2003/page_58.pdf-3
# 10    MRO/2008/page_69.pdf-1
# 11    ZBH/2017/page_71.pdf-3
# 12   RSG/2015/page_142.pdf-1
# 13    LMT/2005/page_40.pdf-2
# 14      V/2008/page_17.pdf-2
# 15   ETR/2008/page_355.pdf-3
# 16    MAS/2012/page_70.pdf-2
# 17    AMT/2005/page_85.pdf-1
# 18    VTR/2007/page_47.pdf-2
# 19   APTV/2014/page_49.pdf-3
# 20    GPN/2017/page_77.pdf-1
# 21   AMAT/2014/page_18.pdf-2
# 22   ABMD/2007/page_52.pdf-2
# 23   SNPS/2006/page_69.pdf-4
# 24   AES/2015/page_117.pdf-4
# 25     UA/2015/page_71.pdf-1
# 26    LMT/2006/page_37.pdf-1
# 27    UNP/2008/page_77.pdf-1
# 28    HII/2014/page_69.pdf-4
# 29  HOLX/2012/page_113.pdf-2
# 30   VRTX/2003/page_71.pdf-1
# 31    IPG/2008/page_62.pdf-2
# 32    FIS/2007/page_94.pdf-2
# 33     PM/2017/page_99.pdf-4
# 34   AES/2017/page_157.pdf-2
# 35    IPG/2008/page_93.pdf-4
# 36    MRO/2015/page_18.pdf-2
# 37   ETFC/2011/page_82.pdf-1
# 38   HII/2017/page_124.pdf-3
# 39   ABMD/2009/page_56.pdf-2
# 40   BLK/2013/page_125.pdf-2
# 41    UNP/2011/page_21.pdf-2
# 42    PPG/2011/page_70.pdf-3
# 43    DRE/2007/page_59.pdf-3
# 44   AES/2016/page_185.pdf-2
# 45    CME/2012/page_70.pdf-3
# 46    ETR/2017/page_26.pdf-2
# 47    UNP/2013/page_44.pdf-2
# 48    UNP/2007/page_65.pdf-3
# 49   ABMD/2006/page_75.pdf-4
# 50    UNP/2006/page_37.pdf-1
# 51    VLO/2018/page_25.pdf-1
# 52  HOLX/2007/page_128.pdf-1
# 53   AAPL/2014/page_38.pdf-2
# 54    GPN/2017/page_77.pdf-2
# 55   PNC/2018/page_171.pdf-1
# 56     PM/2015/page_85.pdf-4
#
#                                               context  \
# 0   the sales of 2014 is $ 450.4 ; the sales of 20...
# 1   beginning of year the revisions of previous es...
# 2   paymentdate the 2015 of amountper share is $ 1...
# 3   ( dollars in millions ) the 2015 of december 3...
# 4   years ended december 31, the 2006 to 2010 of f...
# 5   current assets the property plant and equipmen...
# 6   the weighted average common shares outstanding...
# 7   the 2016 net revenue of amount ( in millions )...
# 8   in millions the sales of 2006 is $ 2455 ; the ...
# 9   the finished goods of 2003 is $ 384.3 ; the fi...
# 10  benchmark wti crude oil ( dollars per barrel )...
# 11  the beginning balance of december 31 2017 is $...
# 12  year the 2016 of gallons hedged is 27000000 ; ...
# 13  ( in millions ) the standby letters of credit ...
# 14  company the visa inc. ( 1 ) of payments volume...
# 15  the 2007 net revenue of amount ( in millions )...
# 16  the cabinets and related products of gross goo...
# 17  the american tower credit facility of 2005 is ...
# 18  the october 1 through october 31 of number of ...
# 19  company index the delphi automotive plc ( 1 ) ...
# 20  cash the customer-related intangible assets of...
# 21  the silicon systems group of 2014 is $ 1400 ; ...
# 22  contractual obligations the operating lease ob...
# 23  the cash paid of ( in thousands ) is $ 11001 ;...
# 24  calculation of proportional free cash flow ( i...
# 25  ( in thousands ) the net revenues of year ende...
# 26  period the october of total number ofshares pu...
# 27  millions of dollars the accounts payable of de...
# 28  ( $ in millions ) the ingalls of december 31 2...
# 29  cash paid the deferred payment of $ 3967866 is...
# 30  common stock under stock and option plans the ...
# 31  the liability at december 31 2006 of 2007 prog...
# 32  2008 the 2009 of 83382 is 63060 ;2008 the 2010...
# 33  ( in millions ) the net earnings attributable ...
# 34  year ended december 31, the us sbu of total re...
# 35  the deferred acquisition payments of 2009 is $...
# 36  ( in thousands ) the u.s . of net undeveloped ...
# 37  reporting unit the u.s . brokerage of december...
# 38  plan category the equity compensation plans ap...
# 39  contractual obligations the operating lease co...
# 40  year the 2014 of amount is $ 135 ;year the 201...
# 41  period the oct . 1 through oct . 31 of total n...
# 42  ( millions ) the royalty income of 2011 is 55 ...
# 43  operating rental properties the land held for ...
# 44  december 31, the ipalco common stock of 2016 i...
# 45  ( in millions ) the designated corporate contr...
# 46  the 2015 net revenue of amount ( in millions )...
# 47  the open sites beginning balance of 2013 is 28...
# 48  2008 the 2009 of $ 689 is 542 ;2008 the 2010 o...
# 49  fiscal year ending march 31, the 2007 of opera...
# 50  millions of dollars the track of 2006 is $ 148...
# 51  period the october 2018 of total numberof shar...
# 52  net tangible assets acquired as of july 13 200...
# 53  the cash cash equivalents and marketable secur...
# 54  cash the customer-related intangible assets of...
# 55  in millions the commitments to extend credit o...
# 56  type the u.s . dollar notes of is ( a ) ; the ...
#
#                                              question  \
# 0             what was the operating margin for 2014?
# 1   what would end of year proven reserves be with...
# 2   what was the number of shares issued in 2015 i...
# 3   what is the book to market ratio of the commer...
# 4   in 2005 what was the percentage of the federal...
# 5      what was the net equity in the assets acquired
# 6   what was the change in millions of weighted av...
# 7   in 2016 what was the ratio of the net income i...
# 8   in 2005 what percentage of consumer packaging ...
# 9   what percent of inventory is ready for liquida...
# 10  what is the difference between the high wti cr...
# 11  percent change in fair value of beginning asse...
# 12  what was the ratio of the 2016 hedged gallons ...
# 13  what percent of total commitments expire in 1-...
# 14  what is the average payment volume per transac...
# 15  what is the net change in net revenue during 2...
# 16  what percentage of net goodwill at december 31...
# 17  what was the increase in long-term debt betwee...
# 18  what was the number of shares outstanding as o...
# 19  what is the difference between the highest and...
# 20  what portion of the total identifiable net ass...
# 21  what are the total sales reported in 2012 , ( ...
# 22  how much of the total contractual commitments ...
# 23  what is the percentage of tax and accounting f...
# 24  net cash provided by operating activities incr...
# 25                 what was the profit margin in 2015
# 26  for the the quarter ended december 31 , 2006 w...
# 27  as of december 31 , 2008 what was the percent ...
# 28  what is the percent of the total backlog for i...
# 29  what is the expected yearly stock-based compen...
# 30  what percent of the total common stock plans a...
# 31  what is the change in the balance of liability...
# 32  what portion of the future minimum operating l...
# 33  what was the change in weighted-average shares...
# 34  as of december 31 , 2017 , assuming an average...
# 35  what is the total amount of parent company gua...
# 36  in 2018 , what percentage of undeveloped acres...
# 37  what percentage of total goodwill is attributa...
# 38  in the number of securities to be issued what ...
# 39  what portion of contractual obligations is exp...
# 40  what are the future minimum commitments under ...
# 41  for all of 2011 , approximately how much was s...
# 42  what was royalty income as a percentage of tot...
# 43  what was the percent of the total purchase pri...
# 44  what was the change in millions of ipalco comm...
# 45  what was the percent of minimum total assets a...
# 46  what are the nuclear fuel expenses as a percen...
# 47  what was the net change in the number of envir...
# 48   what percentage of total debt is due after 2012?
# 49  what percentage of total future minimum lease ...
# 50  in 2006 what was the percent of the total inve...
# 51  for the fourth quarter ended december 312018 w...
# 52  what is the fair value of hologic common stock...
# 53  what was the change in property plant and equi...
# 54  what portion of the total purchase considerati...
# 55  in 2018 what was the percent of the total comm...
# 56  what was the change in millions of trade recei...
#
#                                                answer  \
# 0   Step 1: Divide 88.2 by 450.4. This gives the r...
# 1   Step 1: Subtract 57 from 546. This gives the r...
# 2   Step 1: Divide 170 by 1.14. This gives the res...
# 3   Step 1: Divide 264.9 by 266.3. This gives the ...
# 4   Step 1: Divide 397691 by 2157503. This gives t...
# 5   Step 1: Subtract 144 from 2378. This gives the...
# 6   Step 1: Subtract 314.7 from 303.1. This gives ...
# 7   Step 1: Divide 92.9 by 1520.5. This gives the ...
# 8   Step 1: Divide 437 by 2245. This gives the res...
# 9   Step 1: Divide 384.3 by 527.7. This gives the ...
# 10  Step 1: Subtract 114.95 from 145.29. This give...
# 11  Step 1: Divide 3.8 by 78.7. This gives the res...
# 12  Step 1: Divide 27000000 by 12000000. This give...
# 13  Step 1: Divide 524 by 3066. This gives the res...
# 14  Step 1: Divide 55 by 0.6. This gives the resul...
# 15  Step 1: Subtract 231.0 from 252.7. This gives ...
# 16  Step 1: Divide 181 by 1891. This gives the res...
# 17  Step 1: Subtract 3155228 from 3451276. This gi...
# 18  Step 1: Subtract 14669 from 138311810. This gi...
# 19  Step 1: Subtract 110.41 from 179.33. This give...
# 20  Step 1: Divide 45826 by 62154. This gives the ...
# 21  Step 1: Divide 1.2 by 14. This gives the resul...
# 22  Step 1: Divide 8381 by 14090. This gives the r...
# 23  Step 1: Divide 1.6 by 2.8. This gives the resu...
# 24  Step 1: Divide 343 by 1791. This gives the res...
# 25  Step 1: Divide 231277 by 3967008. This gives t...
# 26  Step 1: Divide 447700 by 929400. This gives th...
# 27  Step 1: Divide 367 by 2560. This gives the res...
# 28  Step 1: Divide 8905 by 18038. This gives the r...
# 29  Step 1: Divide 23.2 by 3.5. This gives the res...
# 30  Step 1: Divide 249 by 22203. This gives the re...
# 31  Step 1: Subtract 31.8 from 12.8. This gives th...
# 32  Step 1: Divide 83382 by 249038. This gives the...
# 33  Step 1: Subtract 1549 from 1551. This gives th...
# 34  Step 1: Multiply 246 by 12.12. This gives the ...
# 35  Step 1: Add 255.7 and 327.1. This gives the re...
# 36  Step 1: Divide 128 by 1018. This gives the res...
# 37  Step 1: Divide 40.6 by 1934.2. This gives the ...
# 38  Step 1: Divide 28763 by 27123. This gives the ...
# 39  Step 1: Divide 4619 by 9457. This gives the re...
# 40  Step 1: Divide 127 by 1286. This gives the res...
# 41  Step 1: Multiply 15340810 by 96.08. This gives...
# 42  Step 1: Divide 45 by 150. This gives the resul...
# 43  Step 1: Multiply 66.1 by 89.7. This gives the ...
# 44  Step 1: Subtract 460 from 618. This gives the ...
# 45  Step 1: Divide 2899.5 by 10973.1. This gives t...
# 46  Step 1: Divide 68 by 1542. This gives the resu...
# 47  Step 1: Subtract 285 from 284. This gives the ...
# 48  Step 1: Divide 4717 by 7680. This gives the re...
# 49  Step 1: Divide 1035 by 4819. This gives the re...
# 50  Step 1: Divide 1487 by 2242. This gives the re...
# 51  Step 1: Divide 3655945 by 7673266. This gives ...
# 52  Step 1: Divide 205500 by 4400. This gives the ...
# 53  Step 1: Subtract 16597 from 20624. This gives ...
# 54  Step 1: Divide 203828 by 265982. This gives th...
# 55  Step 1: Divide 16944 by 181612. This gives the...
# 56  Step 1: Subtract 120 from 888. This gives the ...
#
#                                                 table  \
# 0   [['', '2014', '2013', '2012'], ['Sales', '$450...
# 1   [['Beginning of year', '552'], ['Revisions of ...
# 2   [['PaymentDate', 'Amountper Share', 'TotalAmou...
# 3   [['', 'December 31,'], ['(Dollars in millions)...
# 4   [['Years ended December 31,', 'Federal', 'Stat...
# 5   [['Current assets', '$23'], ['Property, plant ...
# 6   [['', '2017', '2016', '2015'], ['Weighted aver...
# 7   [['', 'Amount (In Millions)'], ['2016 net reve...
# 8   [['<i>In millions</i>', '2006', '2005', '2004'...
# 9   [['', '2003', '2002'], ['Finished goods', '$38...
# 10  [['Benchmark', 'High', 'Date', 'Low', 'Date'],...
# 11  [['', 'December 31, 2017'], ['Beginning Balanc...
# 12  [['Year', 'Gallons Hedged', 'Weighted Average ...
# 13  [['', '<i>Commitment Expiration By Period</i>'...
# 14  [['Company', 'Payments Volume  (billions)', 'T...
# 15  [['', 'Amount (In Millions)'], ['2007 net reve...
# 16  [['', 'Gross  Goodwill At  December 31, 2010',...
# 17  [['', '2005', '2004'], ['American Tower credit...
# 18  [['', 'Number of Shares Repurchased (1)', 'Ave...
# 19  [['Company Index', 'November 17, 2011', 'Decem...
# 20  [['Cash', '$45,826'], ['Customer-related intan...
# 21  [['', '2014', '2013', '', '(In millions, excep...
# 22  [['', 'Payments Due By Fiscal Year'], ['Contra...
# 23  [['', '(in thousands)'], ['Cash paid', '$11,00...
# 24  [['Calculation of Proportional Free Cash Flow ...
# 25  [['', 'Year ended December 31,'], ['(In thousa...
# 26  [['<i>Period</i>', '<i>Total Number of</i><i>S...
# 27  [['<i>Millions of Dollars</i>', '<i>Dec. 31, 2...
# 28  [['', 'December 31, 2014', 'December 31, 2013'...
# 29  [['Cash paid', '$3,967,866'], ['Deferred payme...
# 30  [['Common stock under stock and option plans',...
# 31  [['', '2007 Program', '2003 Program', '2001 Pr...
# 32  [['2008', '83,382'], ['2009', '63,060'], ['201...
# 33  [['', 'For the Years Ended December 31,'], ['(...
# 34  [['', 'Total Revenue'], ['Year Ended December ...
# 35  [['', '2009', '2010', '2011', '2012', '2013', ...
# 36  [['', 'Net Undeveloped Acres Expiring Year End...
# 37  [['Reporting Unit', 'December 31, 2011'], ['U....
# 38  [['Plan category', 'Number of Securities to be...
# 39  [['', 'Payments Due By Fiscal Year  (in $000’s...
# 40  [['Year', 'Amount'], ['2014', '$135'], ['2015'...
# 41  [['<i>Period</i>', '<i>Total Number ofSharesPu...
# 42  [['<i>(Millions)</i>', '<i>2011</i>', '<i>2010...
# 43  [['Operating rental properties', '$602,011'], ...
# 44  [['December 31,', '2016', '2015'], ['IPALCO co...
# 45  [['(in millions)', 'CME ClearingAvailable Asse...
# 46  [['', 'Amount (In Millions)'], ['2015 net reve...
# 47  [['', '<i>2013</i>', '<i>2012</i>', '<i>2011</...
# 48  [['2008', '$ 689'], ['2009', '542'], ['2010', ...
# 49  [['Fiscal Year Ending March 31,', 'Operating L...
# 50  [['<i>Millions of Dollars</i>', '<i>2006</i>',...
# 51  [['Period', 'Total Numberof SharesPurchased', ...
# 52  [['Net tangible assets acquired as of July 13,...
# 53  [['', '2014', '2013', '2012'], ['Cash, cash eq...
# 54  [['Cash', '$45,826'], ['Customer-related intan...
# 55  [['In millions', 'December 31 2018', 'December...
# 56  [['Type', '', 'Face Value', 'Interest Rate', '...
#
#                                          answer_steps  num_steps  \
# 0   [{'arg1': '88.2', 'arg2': '450.4', 'op': 'divi...          1
# 1   [{'arg1': '546', 'arg2': '57', 'op': 'minus2-1...          1
# 2   [{'arg1': '170', 'arg2': '1.14', 'op': 'divide...          1
# 3   [{'arg1': '264.9', 'arg2': '266.3', 'op': 'div...          1
# 4   [{'arg1': '397691', 'arg2': '2157503', 'op': '...          1
# 5   [{'arg1': '2378', 'arg2': '144', 'op': 'minus1...          1
# 6   [{'arg1': '303.1', 'arg2': '314.7', 'op': 'min...          1
# 7   [{'arg1': '92.9', 'arg2': '1520.5', 'op': 'div...          1
# 8   [{'arg1': '437', 'arg2': '2245', 'op': 'divide...          1
# 9   [{'arg1': '384.3', 'arg2': '527.7', 'op': 'div...          1
# 10  [{'arg1': '145.29', 'arg2': '114.95', 'op': 'm...          1
# 11  [{'arg1': '3.8', 'arg2': '78.7', 'op': 'divide...          1
# 12  [{'arg1': '27000000', 'arg2': '12000000', 'op'...          1
# 13  [{'arg1': '524', 'arg2': '3066', 'op': 'divide...          1
# 14  [{'arg1': '55', 'arg2': '0.6', 'op': 'divide2-...          1
# 15  [{'arg1': '252.7', 'arg2': '231.0', 'op': 'min...          1
# 16  [{'arg1': '181', 'arg2': '1891', 'op': 'divide...          1
# 17  [{'arg1': '3451276', 'arg2': '3155228', 'op': ...          1
# 18  [{'arg1': '138311810', 'arg2': '14669', 'op': ...          1
# 19  [{'arg1': '179.33', 'arg2': '110.41', 'op': 'm...          1
# 20  [{'arg1': '45826', 'arg2': '62154', 'op': 'div...          1
# 21  [{'arg1': '1.2', 'arg2': '14', 'op': 'divide2-...          1
# 22  [{'arg1': '8381', 'arg2': '14090', 'op': 'divi...          1
# 23  [{'arg1': '1.6', 'arg2': '2.8', 'op': 'divide1...          1
# 24  [{'arg1': '343', 'arg2': '1791', 'op': 'divide...          1
# 25  [{'arg1': '231277', 'arg2': '3967008', 'op': '...          1
# 26  [{'arg1': '447700', 'arg2': '929400', 'op': 'd...          1
# 27  [{'arg1': '367', 'arg2': '2560', 'op': 'divide...          1
# 28  [{'arg1': '8905', 'arg2': '18038', 'op': 'divi...          1
# 29  [{'arg1': '23.2', 'arg2': '3.5', 'op': 'divide...          1
# 30  [{'arg1': '249', 'arg2': '22203', 'op': 'divid...          1
# 31  [{'arg1': '12.8', 'arg2': '31.8', 'op': 'minus...          1
# 32  [{'arg1': '83382', 'arg2': '249038', 'op': 'di...          1
# 33  [{'arg1': '1551', 'arg2': '1549', 'op': 'minus...          1
# 34  [{'arg1': '246', 'arg2': '12.12', 'op': 'multi...          1
# 35  [{'arg1': '255.7', 'arg2': '327.1', 'op': 'add...          1
# 36  [{'arg1': '128', 'arg2': '1018', 'op': 'divide...          1
# 37  [{'arg1': '40.6', 'arg2': '1934.2', 'op': 'div...          1
# 38  [{'arg1': '28763', 'arg2': '27123', 'op': 'div...          1
# 39  [{'arg1': '4619', 'arg2': '9457', 'op': 'divid...          1
# 40  [{'arg1': '127', 'arg2': '1286', 'op': 'divide...          1
# 41  [{'arg1': '15340810', 'arg2': '96.08', 'op': '...          1
# 42  [{'arg1': '45', 'arg2': '150', 'op': 'divide1-...          1
# 43  [{'arg1': '66.1', 'arg2': '89.7', 'op': 'multi...          1
# 44  [{'arg1': '618', 'arg2': '460', 'op': 'minus1-...          1
# 45  [{'arg1': '2899.5', 'arg2': '10973.1', 'op': '...          1
# 46  [{'arg1': '68', 'arg2': '1542', 'op': 'divide2...          1
# 47  [{'arg1': '284', 'arg2': '285', 'op': 'minus1-...          1
# 48  [{'arg1': '4717', 'arg2': '7680', 'op': 'divid...          1
# 49  [{'arg1': '1035', 'arg2': '4819', 'op': 'divid...          1
# 50  [{'arg1': '1487', 'arg2': '2242', 'op': 'divid...          1
# 51  [{'arg1': '3655945', 'arg2': '7673266', 'op': ...          1
# 52  [{'arg1': '205500', 'arg2': '4400', 'op': 'div...          1
# 53  [{'arg1': '20624', 'arg2': '16597', 'op': 'min...          1
# 54  [{'arg1': '203828', 'arg2': '265982', 'op': 'd...          1
# 55  [{'arg1': '16944', 'arg2': '181612', 'op': 'di...          1
# 56  [{'arg1': '888', 'arg2': '120', 'op': 'minus2-...          1
#
#                                          input_prompt  \
# 0   ### Instruction: Act as a financial analyst ad...
# 1   ### Instruction: Act as a financial analyst ad...
# 2   ### Instruction: Act as a financial analyst ad...
# 3   ### Instruction: Act as a financial analyst ad...
# 4   ### Instruction: Act as a financial analyst ad...
# 5   ### Instruction: Act as a financial analyst ad...
# 6   ### Instruction: Act as a financial analyst ad...
# 7   ### Instruction: Act as a financial analyst ad...
# 8   ### Instruction: Act as a financial analyst ad...
# 9   ### Instruction: Act as a financial analyst ad...
# 10  ### Instruction: Act as a financial analyst ad...
# 11  ### Instruction: Act as a financial analyst ad...
# 12  ### Instruction: Act as a financial analyst ad...
# 13  ### Instruction: Act as a financial analyst ad...
# 14  ### Instruction: Act as a financial analyst ad...
# 15  ### Instruction: Act as a financial analyst ad...
# 16  ### Instruction: Act as a financial analyst ad...
# 17  ### Instruction: Act as a financial analyst ad...
# 18  ### Instruction: Act as a financial analyst ad...
# 19  ### Instruction: Act as a financial analyst ad...
# 20  ### Instruction: Act as a financial analyst ad...
# 21  ### Instruction: Act as a financial analyst ad...
# 22  ### Instruction: Act as a financial analyst ad...
# 23  ### Instruction: Act as a financial analyst ad...
# 24  ### Instruction: Act as a financial analyst ad...
# 25  ### Instruction: Act as a financial analyst ad...
# 26  ### Instruction: Act as a financial analyst ad...
# 27  ### Instruction: Act as a financial analyst ad...
# 28  ### Instruction: Act as a financial analyst ad...
# 29  ### Instruction: Act as a financial analyst ad...
# 30  ### Instruction: Act as a financial analyst ad...
# 31  ### Instruction: Act as a financial analyst ad...
# 32  ### Instruction: Act as a financial analyst ad...
# 33  ### Instruction: Act as a financial analyst ad...
# 34  ### Instruction: Act as a financial analyst ad...
# 35  ### Instruction: Act as a financial analyst ad...
# 36  ### Instruction: Act as a financial analyst ad...
# 37  ### Instruction: Act as a financial analyst ad...
# 38  ### Instruction: Act as a financial analyst ad...
# 39  ### Instruction: Act as a financial analyst ad...
# 40  ### Instruction: Act as a financial analyst ad...
# 41  ### Instruction: Act as a financial analyst ad...
# 42  ### Instruction: Act as a financial analyst ad...
# 43  ### Instruction: Act as a financial analyst ad...
# 44  ### Instruction: Act as a financial analyst ad...
# 45  ### Instruction: Act as a financial analyst ad...
# 46  ### Instruction: Act as a financial analyst ad...
# 47  ### Instruction: Act as a financial analyst ad...
# 48  ### Instruction: Act as a financial analyst ad...
# 49  ### Instruction: Act as a financial analyst ad...
# 50  ### Instruction: Act as a financial analyst ad...
# 51  ### Instruction: Act as a financial analyst ad...
# 52  ### Instruction: Act as a financial analyst ad...
# 53  ### Instruction: Act as a financial analyst ad...
# 54  ### Instruction: Act as a financial analyst ad...
# 55  ### Instruction: Act as a financial analyst ad...
# 56  ### Instruction: Act as a financial analyst ad...
#
#                               llama_finetuned_answers  \
# 0   {'Answer': 'Step 1: Divide 88.2 by 450.4. This...
# 1   {'Answer': 'Step 1: Divide 546 by 552. This gi...
# 2   {'Answer': 'Step 1: Divide 170 by 1.14. This g...
# 3   {'Answer': 'Step 1: Divide 17430.8 by 16831.9....
# 4   {'Answer': 'Step 1: Divide 10012 by 5248. This...
# 5   {'Answer': 'Step 1: Divide 2234 by 23. This gi...
# 6   {'Answer': 'Step 1: Divide 314.7 by 310.3. Thi...
# 7   {'Answer': 'Step 1: Divide 1520.5 by 1522.6. T...
# 8   {'Answer': 'Step 1: Divide 121 by 2245. This g...
# 9   {'Answer': 'Step 1: Divide 527.7 by 384.3. Thi...
# 10  {'Answer': 'Step 1: Divide 145.29 by 114.95. T...
# 11  {'Answer': 'Step 1: Divide 3.8 by 78.7. This g...
# 12  {'Answer': 'Step 1: Divide 27000000 by 1200000...
# 13  {'Answer': 'Step 1: Divide 524 by 3066. This g...
# 14  {'Answer': 'Step 1: Divide 55 by 61. This give...
# 15  {'Answer': 'Step 1: Subtract 231.0 from 252.7....
# 16  {'Answer': 'Step 1: Divide 219 by 4216. This g...
# 17  {'Answer': 'Step 1: Divide 3451276 by 3155228....
# 18  {'Answer': 'Step 1: Divide 14669 by 2014. This...
# 19  {'Answer': 'Step 1: Divide 285.81 by 100.00. T...
# 20  {'Answer': 'Step 1: Divide 62154 by 45826. Thi...
# 21  {'Answer': 'Step 1: Divide 2917 by 100. This g...
# 22  {'Answer': 'Step 1: Divide 7669 by 14090. This...
# 23  {'Answer': 'Step 1: Divide 2831 by 15704. This...
# 24  {'Answer': 'Step 1: Divide 924 by 1791. This g...
# 25  {'Answer': 'Step 1: Divide 231277 by 3967008. ...
# 26  {'Answer': 'Step 1: Divide 447700 by 35259488....
# 27  {'Answer': 'Step 1: Divide 367 by 2560. This g...
# 28  {'Answer': 'Step 1: Divide 11832 by 21430. Thi...
# 29  {'Answer': 'Step 1: Divide 2655 by 3972176. Th...
# 30  {'Answer': 'Step 1: Divide 22203 by 249. This ...
# 31  {'Answer': 'Step 1: Divide 12.8 by 29.6. This ...
# 32  {'Answer': 'Step 1: Divide 14860 by 249038. Th...
# 33  {'Answer': 'Step 1: Subtract 1549 from 1551. T...
# 34  {'Answer': 'Step 1: Divide 10530 by 12.12. Thi...
# 35  {'Answer': 'Step 1: Divide 100 by 2. This give...
# 36  {'Answer': 'Step 1: Divide 128 by 1018. This g...
# 37  {'Answer': 'Step 1: Divide 40.6 by 1934.2. Thi...
# 38  {'Answer': 'Step 1: Divide 100000 by 448859. T...
# 39  {'Answer': 'Step 1: Divide 2313 by 20147. This...
# 40  {'Answer': 'Step 1: Divide 127 by 1286. This g...
# 41  {'Answer': 'Step 1: Divide 3915795 by 100.26. ...
# 42  {'Answer': 'Step 1: Divide 45 by 150. This giv...
# 43  {'Answer': 'Step 1: Divide 154300 by 756311. T...
# 44  {'Answer': 'Step 1: Subtract 460 from 618. Thi...
# 45  {'Answer': 'Step 1: Divide 2899.5 by 10973.1. ...
# 46  {'Answer': 'Step 1: Divide 68 by 1542. This gi...
# 47  {'Answer': 'Step 1: Subtract 294 from 285. Thi...
# 48  {'Answer': 'Step 1: Divide 4717 by 7680. This ...
# 49  {'Answer': 'Step 1: Divide 1035 by 4819. This ...
# 50  {'Answer': 'Step 1: Divide 1487 by 2242. This ...
# 51  {'Answer': 'Step 1: Divide 3439476 by 3655945....
# 52  {'Answer': 'Step 1: Divide 220600 by 10200. Th...
# 53  {'Answer': 'Step 1: Divide 20624 by 16597. Thi...
# 54  {'Answer': 'Step 1: Divide 203828 by 265982. T...
# 55  {'Answer': 'Step 1: Divide 16944 by 181612. Th...
# 56  {'Answer': 'Step 1: Subtract 10.0 from 10.0. T...
#
#                                      answer_formatted  \
# 0   {'Answer': 'Step 1: Divide 88.2 by 450.4. This...
# 1   {'Answer': 'Step 1: Subtract 57 from 546. This...
# 2   {'Answer': 'Step 1: Divide 170 by 1.14. This g...
# 3   {'Answer': 'Step 1: Divide 264.9 by 266.3. Thi...
# 4   {'Answer': 'Step 1: Divide 397691 by 2157503. ...
# 5   {'Answer': 'Step 1: Subtract 144 from 2378. Th...
# 6   {'Answer': 'Step 1: Subtract 314.7 from 303.1....
# 7   {'Answer': 'Step 1: Divide 92.9 by 1520.5. Thi...
# 8   {'Answer': 'Step 1: Divide 437 by 2245. This g...
# 9   {'Answer': 'Step 1: Divide 384.3 by 527.7. Thi...
# 10  {'Answer': 'Step 1: Subtract 114.95 from 145.2...
# 11  {'Answer': 'Step 1: Divide 3.8 by 78.7. This g...
# 12  {'Answer': 'Step 1: Divide 27000000 by 1200000...
# 13  {'Answer': 'Step 1: Divide 524 by 3066. This g...
# 14  {'Answer': 'Step 1: Divide 55 by 0.6. This giv...
# 15  {'Answer': 'Step 1: Subtract 231.0 from 252.7....
# 16  {'Answer': 'Step 1: Divide 181 by 1891. This g...
# 17  {'Answer': 'Step 1: Subtract 3155228 from 3451...
# 18  {'Answer': 'Step 1: Subtract 14669 from 138311...
# 19  {'Answer': 'Step 1: Subtract 110.41 from 179.3...
# 20  {'Answer': 'Step 1: Divide 45826 by 62154. Thi...
# 21  {'Answer': 'Step 1: Divide 1.2 by 14. This giv...
# 22  {'Answer': 'Step 1: Divide 8381 by 14090. This...
# 23  {'Answer': 'Step 1: Divide 1.6 by 2.8. This gi...
# 24  {'Answer': 'Step 1: Divide 343 by 1791. This g...
# 25  {'Answer': 'Step 1: Divide 231277 by 3967008. ...
# 26  {'Answer': 'Step 1: Divide 447700 by 929400. T...
# 27  {'Answer': 'Step 1: Divide 367 by 2560. This g...
# 28  {'Answer': 'Step 1: Divide 8905 by 18038. This...
# 29  {'Answer': 'Step 1: Divide 23.2 by 3.5. This g...
# 30  {'Answer': 'Step 1: Divide 249 by 22203. This ...
# 31  {'Answer': 'Step 1: Subtract 31.8 from 12.8. T...
# 32  {'Answer': 'Step 1: Divide 83382 by 249038. Th...
# 33  {'Answer': 'Step 1: Subtract 1549 from 1551. T...
# 34  {'Answer': 'Step 1: Multiply 246 by 12.12. Thi...
# 35  {'Answer': 'Step 1: Add 255.7 and 327.1. This ...
# 36  {'Answer': 'Step 1: Divide 128 by 1018. This g...
# 37  {'Answer': 'Step 1: Divide 40.6 by 1934.2. Thi...
# 38  {'Answer': 'Step 1: Divide 28763 by 27123. Thi...
# 39  {'Answer': 'Step 1: Divide 4619 by 9457. This ...
# 40  {'Answer': 'Step 1: Divide 127 by 1286. This g...
# 41  {'Answer': 'Step 1: Multiply 15340810 by 96.08...
# 42  {'Answer': 'Step 1: Divide 45 by 150. This giv...
# 43  {'Answer': 'Step 1: Multiply 66.1 by 89.7. Thi...
# 44  {'Answer': 'Step 1: Subtract 460 from 618. Thi...
# 45  {'Answer': 'Step 1: Divide 2899.5 by 10973.1. ...
# 46  {'Answer': 'Step 1: Divide 68 by 1542. This gi...
# 47  {'Answer': 'Step 1: Subtract 285 from 284. Thi...
# 48  {'Answer': 'Step 1: Divide 4717 by 7680. This ...
# 49  {'Answer': 'Step 1: Divide 1035 by 4819. This ...
# 50  {'Answer': 'Step 1: Divide 1487 by 2242. This ...
# 51  {'Answer': 'Step 1: Divide 3655945 by 7673266....
# 52  {'Answer': 'Step 1: Divide 205500 by 4400. Thi...
# 53  {'Answer': 'Step 1: Subtract 16597 from 20624....
# 54  {'Answer': 'Step 1: Divide 203828 by 265982. T...
# 55  {'Answer': 'Step 1: Divide 16944 by 181612. Th...
# 56  {'Answer': 'Step 1: Subtract 120 from 888. Thi...
#
#                                   actual_answer_final  \
# 0   {'Answer': 'Step 1: Divide 88.2 by 450.4. This...
# 1   {'Answer': 'Step 1: Subtract 57 from 546. This...
# 2   {'Answer': 'Step 1: Divide 170 by 1.14. This g...
# 3   {'Answer': 'Step 1: Divide 264.9 by 266.3. Thi...
# 4   {'Answer': 'Step 1: Divide 397691 by 2157503. ...
# 5   {'Answer': 'Step 1: Subtract 144 from 2378. Th...
# 6   {'Answer': 'Step 1: Subtract 314.7 from 303.1....
# 7   {'Answer': 'Step 1: Divide 92.9 by 1520.5. Thi...
# 8   {'Answer': 'Step 1: Divide 437 by 2245. This g...
# 9   {'Answer': 'Step 1: Divide 384.3 by 527.7. Thi...
# 10  {'Answer': 'Step 1: Subtract 114.95 from 145.2...
# 11  {'Answer': 'Step 1: Divide 3.8 by 78.7. This g...
# 12  {'Answer': 'Step 1: Divide 27000000 by 1200000...
# 13  {'Answer': 'Step 1: Divide 524 by 3066. This g...
# 14  {'Answer': 'Step 1: Divide 55 by 0.6. This giv...
# 15  {'Answer': 'Step 1: Subtract 231.0 from 252.7....
# 16  {'Answer': 'Step 1: Divide 181 by 1891. This g...
# 17  {'Answer': 'Step 1: Subtract 3155228 from 3451...
# 18  {'Answer': 'Step 1: Subtract 14669 from 138311...
# 19  {'Answer': 'Step 1: Subtract 110.41 from 179.3...
# 20  {'Answer': 'Step 1: Divide 45826 by 62154. Thi...
# 21  {'Answer': 'Step 1: Divide 1.2 by 14. This giv...
# 22  {'Answer': 'Step 1: Divide 8381 by 14090. This...
# 23  {'Answer': 'Step 1: Divide 1.6 by 2.8. This gi...
# 24  {'Answer': 'Step 1: Divide 343 by 1791. This g...
# 25  {'Answer': 'Step 1: Divide 231277 by 3967008. ...
# 26  {'Answer': 'Step 1: Divide 447700 by 929400. T...
# 27  {'Answer': 'Step 1: Divide 367 by 2560. This g...
# 28  {'Answer': 'Step 1: Divide 8905 by 18038. This...
# 29  {'Answer': 'Step 1: Divide 23.2 by 3.5. This g...
# 30  {'Answer': 'Step 1: Divide 249 by 22203. This ...
# 31  {'Answer': 'Step 1: Subtract 31.8 from 12.8. T...
# 32  {'Answer': 'Step 1: Divide 83382 by 249038. Th...
# 33  {'Answer': 'Step 1: Subtract 1549 from 1551. T...
# 34  {'Answer': 'Step 1: Multiply 246 by 12.12. Thi...
# 35  {'Answer': 'Step 1: Add 255.7 and 327.1. This ...
# 36  {'Answer': 'Step 1: Divide 128 by 1018. This g...
# 37  {'Answer': 'Step 1: Divide 40.6 by 1934.2. Thi...
# 38  {'Answer': 'Step 1: Divide 28763 by 27123. Thi...
# 39  {'Answer': 'Step 1: Divide 4619 by 9457. This ...
# 40  {'Answer': 'Step 1: Divide 127 by 1286. This g...
# 41  {'Answer': 'Step 1: Multiply 15340810 by 96.08...
# 42  {'Answer': 'Step 1: Divide 45 by 150. This giv...
# 43  {'Answer': 'Step 1: Multiply 66.1 by 89.7. Thi...
# 44  {'Answer': 'Step 1: Subtract 460 from 618. Thi...
# 45  {'Answer': 'Step 1: Divide 2899.5 by 10973.1. ...
# 46  {'Answer': 'Step 1: Divide 68 by 1542. This gi...
# 47  {'Answer': 'Step 1: Subtract 285 from 284. Thi...
# 48  {'Answer': 'Step 1: Divide 4717 by 7680. This ...
# 49  {'Answer': 'Step 1: Divide 1035 by 4819. This ...
# 50  {'Answer': 'Step 1: Divide 1487 by 2242. This ...
# 51  {'Answer': 'Step 1: Divide 3655945 by 7673266....
# 52  {'Answer': 'Step 1: Divide 205500 by 4400. Thi...
# 53  {'Answer': 'Step 1: Subtract 16597 from 20624....
# 54  {'Answer': 'Step 1: Divide 203828 by 265982. T...
# 55  {'Answer': 'Step 1: Divide 16944 by 181612. Th...
# 56  {'Answer': 'Step 1: Subtract 120 from 888. Thi...
#
#                               finetuned_answers_final  \
# 0   {'Answer': 'Step 1: Divide 88.2 by 450.4. This...
# 1   {'Answer': 'Step 1: Divide 546 by 552. This gi...
# 2   {'Answer': 'Step 1: Divide 170 by 1.14. This g...
# 3   {'Answer': 'Step 1: Divide 17430.8 by 16831.9....
# 4   {'Answer': 'Step 1: Divide 10012 by 5248. This...
# 5   {'Answer': 'Step 1: Divide 2234 by 23. This gi...
# 6   {'Answer': 'Step 1: Divide 314.7 by 310.3. Thi...
# 7   {'Answer': 'Step 1: Divide 1520.5 by 1522.6. T...
# 8   {'Answer': 'Step 1: Divide 121 by 2245. This g...
# 9   {'Answer': 'Step 1: Divide 527.7 by 384.3. Thi...
# 10  {'Answer': 'Step 1: Divide 145.29 by 114.95. T...
# 11  {'Answer': 'Step 1: Divide 3.8 by 78.7. This g...
# 12  {'Answer': 'Step 1: Divide 27000000 by 1200000...
# 13  {'Answer': 'Step 1: Divide 524 by 3066. This g...
# 14  {'Answer': 'Step 1: Divide 55 by 61. This give...
# 15  {'Answer': 'Step 1: Subtract 231.0 from 252.7....
# 16  {'Answer': 'Step 1: Divide 219 by 4216. This g...
# 17  {'Answer': 'Step 1: Divide 3451276 by 3155228....
# 18  {'Answer': 'Step 1: Divide 14669 by 2014. This...
# 19  {'Answer': 'Step 1: Divide 285.81 by 100.00. T...
# 20  {'Answer': 'Step 1: Divide 62154 by 45826. Thi...
# 21  {'Answer': 'Step 1: Divide 2917 by 100. This g...
# 22  {'Answer': 'Step 1: Divide 7669 by 14090. This...
# 23  {'Answer': 'Step 1: Divide 2831 by 15704. This...
# 24  {'Answer': 'Step 1: Divide 924 by 1791. This g...
# 25  {'Answer': 'Step 1: Divide 231277 by 3967008. ...
# 26  {'Answer': 'Step 1: Divide 447700 by 35259488....
# 27  {'Answer': 'Step 1: Divide 367 by 2560. This g...
# 28  {'Answer': 'Step 1: Divide 11832 by 21430. Thi...
# 29  {'Answer': 'Step 1: Divide 2655 by 3972176. Th...
# 30  {'Answer': 'Step 1: Divide 22203 by 249. This ...
# 31  {'Answer': 'Step 1: Divide 12.8 by 29.6. This ...
# 32  {'Answer': 'Step 1: Divide 14860 by 249038. Th...
# 33  {'Answer': 'Step 1: Subtract 1549 from 1551. T...
# 34  {'Answer': 'Step 1: Divide 10530 by 12.12. Thi...
# 35  {'Answer': 'Step 1: Divide 100 by 2. This give...
# 36  {'Answer': 'Step 1: Divide 128 by 1018. This g...
# 37  {'Answer': 'Step 1: Divide 40.6 by 1934.2. Thi...
# 38  {'Answer': 'Step 1: Divide 100000 by 448859. T...
# 39  {'Answer': 'Step 1: Divide 2313 by 20147. This...
# 40  {'Answer': 'Step 1: Divide 127 by 1286. This g...
# 41  {'Answer': 'Step 1: Divide 3915795 by 100.26. ...
# 42  {'Answer': 'Step 1: Divide 45 by 150. This giv...
# 43  {'Answer': 'Step 1: Divide 154300 by 756311. T...
# 44  {'Answer': 'Step 1: Subtract 460 from 618. Thi...
# 45  {'Answer': 'Step 1: Divide 2899.5 by 10973.1. ...
# 46  {'Answer': 'Step 1: Divide 68 by 1542. This gi...
# 47  {'Answer': 'Step 1: Subtract 294 from 285. Thi...
# 48  {'Answer': 'Step 1: Divide 4717 by 7680. This ...
# 49  {'Answer': 'Step 1: Divide 1035 by 4819. This ...
# 50  {'Answer': 'Step 1: Divide 1487 by 2242. This ...
# 51  {'Answer': 'Step 1: Divide 3439476 by 3655945....
# 52  {'Answer': 'Step 1: Divide 220600 by 10200. Th...
# 53  {'Answer': 'Step 1: Divide 20624 by 16597. Thi...
# 54  {'Answer': 'Step 1: Divide 203828 by 265982. T...
# 55  {'Answer': 'Step 1: Divide 16944 by 181612. Th...
# 56  {'Answer': 'Step 1: Subtract 10.0 from 10.0. T...
#
#                                       evaluation_dict  \
# 0   {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 1   {'operator_match': 0, 'arg1_match': 0, 'arg2_m...
# 2   {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 3   {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 4   {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 5   {'operator_match': 0, 'arg1_match': 0, 'arg2_m...
# 6   {'operator_match': 0, 'arg1_match': 1, 'arg2_m...
# 7   {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 8   {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 9   {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 10  {'operator_match': 0, 'arg1_match': 0, 'arg2_m...
# 11  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 12  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 13  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 14  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 15  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 16  {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 17  {'operator_match': 0, 'arg1_match': 0, 'arg2_m...
# 18  {'operator_match': 0, 'arg1_match': 1, 'arg2_m...
# 19  {'operator_match': 0, 'arg1_match': 0, 'arg2_m...
# 20  {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 21  {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 22  {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 23  {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 24  {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 25  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 26  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 27  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 28  {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 29  {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 30  {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 31  {'operator_match': 0, 'arg1_match': 0, 'arg2_m...
# 32  {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 33  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 34  {'operator_match': 0, 'arg1_match': 0, 'arg2_m...
# 35  {'operator_match': 0, 'arg1_match': 0, 'arg2_m...
# 36  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 37  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 38  {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 39  {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 40  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 41  {'operator_match': 0, 'arg1_match': 0, 'arg2_m...
# 42  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 43  {'operator_match': 0, 'arg1_match': 0, 'arg2_m...
# 44  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 45  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 46  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 47  {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 48  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 49  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 50  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 51  {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 52  {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
# 53  {'operator_match': 0, 'arg1_match': 0, 'arg2_m...
# 54  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 55  {'operator_match': 1, 'arg1_match': 1, 'arg2_m...
# 56  {'operator_match': 1, 'arg1_match': 0, 'arg2_m...
#
#                                          rogue_scores
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  {'rouge1': 0.3283582089552239, 'rouge2': 0.0, ...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  {'rouge1': 0.6493506493506493, 'rouge2': 0.0, ...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36  {'rouge1': 0.7671232876712328, 'rouge2': 0.0, ...
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40  {'rouge1': 0.726027397260274, 'rouge2': 0.0, '...
# 41                                                NaN
# 42  {'rouge1': 0.7611940298507462, 'rouge2': 0.0, ...
# 43                                                NaN
# 44  {'rouge1': 0.8, 'rouge2': 0.0, 'rougeL': 0.8, ...
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54  {'rouge1': 0.7831325301204819, 'rouge2': 0.0, ...
# 55                                                NaN
# 56                                                NaN
